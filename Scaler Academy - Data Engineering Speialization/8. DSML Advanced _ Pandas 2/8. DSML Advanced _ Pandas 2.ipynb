# %%
import pandas as pd
import numpy as np

# %%
a = pd.DataFrame({'A':[10,30], 'B':[20,40]})
b = pd.DataFrame({'A':[10,30], 'C':[20,40]})

# %%
a
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
b
# Out:
#     A   C
# 0  10  20
# 1  30  40

# %%
pd.concat([a, b])
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %%
pd.concat([a, b], axis=1)
# Out:
#     A   B   A   C
# 0  10  20  10  20
# 1  30  40  30  40

# %%
pd.concat([a, b], axis=0, join='outer')
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %%
pd.concat([a, b], axis=0, join='inner')
# Out:
#     A
# 0  10
# 1  30
# 0  10
# 1  30

# %% [markdown]
# ## pd.merge()

# %%
users = pd.DataFrame({'userid':[1, 2, 3], 'name':['A', 'B', 'C']})
msgs = pd.DataFrame({'userid':[1, 1, 2], 'msg':['hello', 'bye', 'hi']})

# %%
users
# Out:
#    userid name
# 0       1    A
# 1       2    B
# 2       3    C

# %%
msgs
# Out:
#    userid    msg
# 0       1  hello
# 1       1    bye
# 2       2     hi

# %%
pd.concat((users, msgs))
# Out:
#    userid name    msg
# 0       1    A    NaN
# 1       2    B    NaN
# 2       3    C    NaN
# 0       1  NaN  hello
# 1       1  NaN    bye
# 2       2  NaN     hi

# %%
pd.merge(users, msgs, on='userid')
# Out:
#    userid name    msg
# 0       1    A  hello
# 1       1    A    bye
# 2       2    B     hi

# %%
users.rename(columns={'userid' :'id'}, inplace=True)
users
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
msgs
# Out:
#    userid    msg
# 0       1  hello
# 1       1    bye
# 2       2     hi

# %%
pd.merge(users, msgs, left_on='id', right_on='userid')
# Out:
#    id name  userid    msg
# 0   1    A       1  hello
# 1   1    A       1    bye
# 2   2    B       2     hi

# %%
pd.merge(users, msgs, how='inner' , left_on='id', right_on='userid')
# Out:
#    id name  userid    msg
# 0   1    A       1  hello
# 1   1    A       1    bye
# 2   2    B       2     hi

# %%
users
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
msgs
# Out:
#    userid    msg
# 0       1  hello
# 1       1    bye
# 2       2     hi

# %%
pd.merge(users, msgs, how='left' , left_on='id', right_on='userid')
# Out:
#    id name  userid    msg
# 0   1    A     1.0  hello
# 1   1    A     1.0    bye
# 2   2    B     2.0     hi
# 3   3    C     NaN    NaN

# %%
pd.merge(users, msgs, how='right' , left_on='id', right_on='userid')
# Out:
#    id name  userid    msg
# 0   1    A       1  hello
# 1   1    A       1    bye
# 2   2    B       2     hi

# %%
pd.merge(users, msgs, how='outer' , left_on='id', right_on='userid')
# Out:
#    id name  userid    msg
# 0   1    A     1.0  hello
# 1   1    A     1.0    bye
# 2   2    B     2.0     hi
# 3   3    C     NaN    NaN

# %%
users
# Out:
#    id name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
users = users[['name', 'id']]
users
# Out:
#   name  id
# 0    A   1
# 1    B   2
# 2    C   3

# %%
df = pd.read_csv('gapminder.csv')
df.head()
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 0  Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088    13079460  739.981106

# %%
df.shape
# Out:
# (1704, 6)

# %%
mask = df['lifeExp'] > 60
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699     True
# 1700     True
# 1701    False
# 1702    False
# 1703    False
# Name: lifeExp, Length: 1704, dtype: bool

# %%
df[mask]
# Out:
#           country continent  year  lifeExp  population    gdpPerCap
# 14        Albania    Europe  1962   64.820     1728137  2312.888958
# 15        Albania    Europe  1967   66.220     1984060  2760.196931
# 16        Albania    Europe  1972   67.690     2263554  3313.422188
# 17        Albania    Europe  1977   68.930     2509048  3533.003910
# 18        Albania    Europe  1982   70.420     2780097  3630.880722
# ...           ...       ...   ...      ...         ...          ...
# 1678  Yemen, Rep.      Asia  2002   60.308    18701257  2234.820827
# 1679  Yemen, Rep.      Asia  2007   62.698    22211743  2280.769906
# 1698     Zimbabwe    Africa  1982   60.363     7636524   788.855041
# 1699     Zimbabwe    Africa  1987   62.351     9216418   706.157306
# 1700     Zimbabwe    Africa  1992   60.377    10704340   693.420786
#
# [877 rows x 6 columns]

# %%
df[ df['lifeExp']>60 ]['country']
# Out:
# 14          Albania
# 15          Albania
# 16          Albania
# 17          Albania
# 18          Albania
#            ...
# 1678    Yemen, Rep.
# 1679    Yemen, Rep.
# 1698       Zimbabwe
# 1699       Zimbabwe
# 1700       Zimbabwe
# Name: country, Length: 877, dtype: object

# %%
df.loc[ df['lifeExp']>60  , ['country', 'lifeExp'] ]
# Out:
#           country  lifeExp
# 14        Albania   64.820
# 15        Albania   66.220
# 16        Albania   67.690
# 17        Albania   68.930
# 18        Albania   70.420
# ...           ...      ...
# 1678  Yemen, Rep.   60.308
# 1679  Yemen, Rep.   62.698
# 1698     Zimbabwe   60.363
# 1699     Zimbabwe   62.351
# 1700     Zimbabwe   60.377
#
# [877 rows x 2 columns]

# %%
df
# Out:
#           country continent  year  lifeExp  population   gdpPerCap
# 0     Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088    13079460  739.981106
# ...           ...       ...   ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487    12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df[(df['country'] == 'Zimbabwe')]
# Out:
#        country continent  year  lifeExp  population   gdpPerCap
# 1692  Zimbabwe    Africa  1952   48.451     3080907  406.884115
# 1693  Zimbabwe    Africa  1957   50.469     3646340  518.764268
# 1694  Zimbabwe    Africa  1962   52.358     4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995     4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635     5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674     6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363     7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487    12311143  469.709298

# %%
len(df[(df['country'] == 'Zimbabwe')])
# Out:
# 12

# %%
df[(df['lifeExp'] >30) & (df['lifeExp'] <40)]
# Out:
#           country continent  year  lifeExp  population    gdpPerCap
# 1     Afghanistan      Asia  1957   30.332     9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997    10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020    11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088    13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438    14880372   786.113360
# ...           ...       ...   ...      ...         ...          ...
# 1670  Yemen, Rep.      Asia  1962   35.180     6120081   825.623201
# 1671  Yemen, Rep.      Asia  1967   36.984     6740785   862.442146
# 1672  Yemen, Rep.      Asia  1972   39.848     7407075  1265.047031
# 1690       Zambia    Africa  2002   39.193    10595811  1071.613938
# 1702     Zimbabwe    Africa  2002   39.989    11926563   672.038623
#
# [121 rows x 6 columns]

# %%
df[ (df['country'] == 'Kenya') | (df['country'] == 'Egypt') ]
# Out:
#     country continent  year  lifeExp  population    gdpPerCap
# 456   Egypt    Africa  1952   41.893    22223309  1418.822445
# 457   Egypt    Africa  1957   44.444    25009741  1458.915272
# 458   Egypt    Africa  1962   46.992    28173309  1693.335853
# 459   Egypt    Africa  1967   49.293    31681188  1814.880728
# 460   Egypt    Africa  1972   51.137    34807417  2024.008147
# 461   Egypt    Africa  1977   53.319    38783863  2785.493582
# 462   Egypt    Africa  1982   56.006    45681811  3503.729636
# 463   Egypt    Africa  1987   59.797    52799062  3885.460710
# 464   Egypt    Africa  1992   63.674    59402198  3794.755195
# 465   Egypt    Africa  1997   67.217    66134291  4173.181797
# 466   Egypt    Africa  2002   69.806    73312559  4754.604414
# 467   Egypt    Africa  2007   71.338    80264543  5581.180998
# 816   Kenya    Africa  1952   42.270     6464046   853.540919
# 817   Kenya    Africa  1957   44.686     7454779   944.438315
# ...

# %%
not False
# Out:
# True

# %%
df[~(df['country'] == 'Kenya')]
# Out:
#           country continent  year  lifeExp  population   gdpPerCap
# 0     Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088    13079460  739.981106
# ...           ...       ...   ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487    12311143  469.709298
#
# [1692 rows x 6 columns]

# %%
df
# Out:
#           country continent  year  lifeExp  population   gdpPerCap
# 0     Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088    13079460  739.981106
# ...           ...       ...   ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487    12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df[df['continent'] == 'Asia']['lifeExp'].mean()
# Out:
# 60.064903232323175

# %%
df[df['continent'] == 'Africa']['lifeExp'].mean()
# Out:
# 48.86533012820508

# %%
df['continent'].nunique()
# Out:
# 5

# %%
df['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
df['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
# 21st century countries having less than 1000 gdp

# %%
df.loc[(df['year'] > 2000) & (df['gdpPerCap'] < 1000),'country'].value_counts()
# Out:
# Gambia                      2
# Rwanda                      2
# Togo                        2
# Liberia                     2
# Congo, Dem. Rep.            2
# Burundi                     2
# Mozambique                  2
# Myanmar                     2
# Zimbabwe                    2
# Sierra Leone                2
# Central African Republic    2
# Guinea                      2
# Eritrea                     2
# Niger                       2
# Ethiopia                    2
# Guinea-Bissau               2
# Somalia                     2
# Afghanistan                 2
# Malawi                      2
# Cambodia                    1
# Madagascar                  1
# Mali                        1
# Uganda                      1
# Comoros                     1
# Tanzania                    1
# Name: country, dtype: int64

# %%
string ="How much wood would a woodchuck chuck if a woodchuck could chuck wood"

# %%
pd.Series(string.split()).value_counts()
# Out:
# woodchuck    2
# wood         2
# chuck        2
# a            2
# How          1
# much         1
# if           1
# could        1
# would        1
# dtype: int64

# %% [markdown]
# # Grouping

# %%
df.groupby(by='continent')['lifeExp'].mean()
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExp, dtype: float64

# %%
df.groupby(by='continent')['lifeExp'].min()
# Out:
# continent
# Africa      23.599
# Americas    37.579
# Asia        28.801
# Europe      43.585
# Oceania     69.120
# Name: lifeExp, dtype: float64

# %%
df.groupby(by='continent').mean()[['lifeExp', 'gdpPerCap']]
# Out:
#              lifeExp     gdpPerCap
# continent
# Africa     48.865330   2193.754578
# Americas   64.658737   7136.110356
# Asia       60.064903   7902.150428
# Europe     71.903686  14469.475533
# Oceania    74.326208  18621.609223

# %%
g = df.groupby(by='continent')
g

# %%
g.mean()
# Out:
#              year    lifeExp    population     gdpPerCap
# continent
# Africa     1979.5  48.865330  9.916003e+06   2193.754578
# Americas   1979.5  64.658737  2.450479e+07   7136.110356
# Asia       1979.5  60.064903  7.703872e+07   7902.150428
# Europe     1979.5  71.903686  1.716976e+07  14469.475533
# Oceania    1979.5  74.326208  8.874672e+06  18621.609223

# %%
g.get_group('Asia')
# Out:
#           country continent  year  lifeExp  population    gdpPerCap
# 0     Afghanistan      Asia  1952   28.801     8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332     9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997    10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020    11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088    13079460   739.981106
# ...           ...       ...   ...      ...         ...          ...
# 1675  Yemen, Rep.      Asia  1987   52.922    11219340  1971.741538
# 1676  Yemen, Rep.      Asia  1992   55.599    13367997  1879.496673
# 1677  Yemen, Rep.      Asia  1997   58.020    15826497  2117.484526
# 1678  Yemen, Rep.      Asia  2002   60.308    18701257  2234.820827
# 1679  Yemen, Rep.      Asia  2007   62.698    22211743  2280.769906
#
# [396 rows x 6 columns]

# %%
temp = g.aggregate(func= ['min', 'max', 'mean', np.median ])[['lifeExp', 'gdpPerCap'] ]
temp
# Out:
#           lifeExp                                 gdpPerCap                \
#               min     max       mean   median           min           max
# continent
# Africa     23.599  76.442  48.865330  47.7920    241.165876   21951.21176
# Americas   37.579  80.653  64.658737  67.0480   1201.637154   42951.65309
# Asia       28.801  82.603  60.064903  61.7915    331.000000  113523.13290
# Europe     43.585  81.757  71.903686  72.2410    973.533195   49357.19017
# Oceania    69.120  81.235  74.326208  73.6650  10039.595640   34435.36744
#
#
#                    mean        median
# continent
# Africa      2193.754578   1192.138217
# Americas    7136.110356   5465.509853
# Asia        7902.150428   2646.786844
# Europe     14469.475533  12081.749115
# Oceania    18621.609223  17983.303955

# %%
temp['gdpPerCap']
# Out:
#                     min           max          mean        median
# continent
# Africa       241.165876   21951.21176   2193.754578   1192.138217
# Americas    1201.637154   42951.65309   7136.110356   5465.509853
# Asia         331.000000  113523.13290   7902.150428   2646.786844
# Europe       973.533195   49357.19017  14469.475533  12081.749115
# Oceania    10039.595640   34435.36744  18621.609223  17983.303955

# %%
temp[('gdpPerCap', 'max')]
# Out:
# continent
# Africa       21951.21176
# Americas     42951.65309
# Asia        113523.13290
# Europe       49357.19017
# Oceania      34435.36744
# Name: (gdpPerCap, max), dtype: float64

# %%
df.groupby(by=['continent', 'year']).mean()[['lifeExp', 'gdpPerCap'] ]
# Out:
#                   lifeExp     gdpPerCap
# continent year
# Africa    1952  39.135500   1252.572466
#           1957  41.266346   1385.236062
#           1962  43.319442   1598.078825
#           1967  45.334538   2050.363801
#           1972  47.450942   2339.615674
#           1977  49.580423   2585.938508
#           1982  51.592865   2481.592960
#           1987  53.344788   2282.668991
#           1992  53.629577   2281.810333
#           1997  53.598269   2378.759555
#           2002  53.325231   2599.385159
#           2007  54.806038   3089.032605
# Americas  1952  53.279840   4079.062552
#           1957  55.960280   4616.043733
#           1962  58.398760   4901.541870
#           1967  60.410920   5668.253496
#           1972  62.394920   6491.334139
#           1977  64.391560   7352.007126
#           1982  66.228840   7506.737088
#           1987  68.090720   7793.400261
#           1992  69.568360   8044.934406
#           1997  71.150480   8889.300863
# ...

# %%
df.groupby(by=['year']).mean()[['lifeExp', 'gdpPerCap'] ]
# Out:
#         lifeExp     gdpPerCap
# year
# 1952  49.057620   3725.276046
# 1957  51.507401   4299.408345
# 1962  53.609249   4725.812342
# 1967  55.678290   5483.653047
# 1972  57.647386   6770.082815
# 1977  59.570157   7313.166421
# 1982  61.533197   7518.901673
# 1987  63.212613   7900.920218
# 1992  64.160338   8158.608521
# 1997  65.014676   9090.175363
# 2002  65.694923   9917.848365
# 2007  67.007423  11680.071820

# %%
temp = df.groupby(by=['continent', 'year']).mean()[['lifeExp', 'gdpPerCap'] ]
temp
# Out:
#                   lifeExp     gdpPerCap
# continent year
# Africa    1952  39.135500   1252.572466
#           1957  41.266346   1385.236062
#           1962  43.319442   1598.078825
#           1967  45.334538   2050.363801
#           1972  47.450942   2339.615674
#           1977  49.580423   2585.938508
#           1982  51.592865   2481.592960
#           1987  53.344788   2282.668991
#           1992  53.629577   2281.810333
#           1997  53.598269   2378.759555
#           2002  53.325231   2599.385159
#           2007  54.806038   3089.032605
# Americas  1952  53.279840   4079.062552
#           1957  55.960280   4616.043733
#           1962  58.398760   4901.541870
#           1967  60.410920   5668.253496
#           1972  62.394920   6491.334139
#           1977  64.391560   7352.007126
#           1982  66.228840   7506.737088
#           1987  68.090720   7793.400261
#           1992  69.568360   8044.934406
#           1997  71.150480   8889.300863
# ...

# %%
temp.iloc[-1, :]
# Out:
# lifeExp         80.719500
# gdpPerCap    29810.188275
# Name: (Oceania, 2007), dtype: float64

# %%
temp.loc[('Africa', 1957)]
# Out:
# lifeExp        41.266346
# gdpPerCap    1385.236062
# Name: (Africa, 1957), dtype: float64

# %%
temp.reset_index()
# Out:
#    continent  year    lifeExp     gdpPerCap
# 0     Africa  1952  39.135500   1252.572466
# 1     Africa  1957  41.266346   1385.236062
# 2     Africa  1962  43.319442   1598.078825
# 3     Africa  1967  45.334538   2050.363801
# 4     Africa  1972  47.450942   2339.615674
# 5     Africa  1977  49.580423   2585.938508
# 6     Africa  1982  51.592865   2481.592960
# 7     Africa  1987  53.344788   2282.668991
# 8     Africa  1992  53.629577   2281.810333
# 9     Africa  1997  53.598269   2378.759555
# 10    Africa  2002  53.325231   2599.385159
# 11    Africa  2007  54.806038   3089.032605
# 12  Americas  1952  53.279840   4079.062552
# 13  Americas  1957  55.960280   4616.043733
# 14  Americas  1962  58.398760   4901.541870
# 15  Americas  1967  60.410920   5668.253496
# 16  Americas  1972  62.394920   6491.334139
# 17  Americas  1977  64.391560   7352.007126
# 18  Americas  1982  66.228840   7506.737088
# 19  Americas  1987  68.090720   7793.400261
# ...

# %%
df.groupby(['continent', 'year']).aggregate({'year' : 'count', 'population' :'sum'})
# Out:
#                 year  population
# continent year
# Africa    1952    52   237640501
#           1957    52   264837738
#           1962    52   296516865
#           1967    52   335289489
#           1972    52   379879541
#           1977    52   433061021
#           1982    52   499348587
#           1987    52   574834110
#           1992    52   659081517
#           1997    52   743832984
#           2002    52   833723916
#           2007    52   929539692
# Americas  1952    25   345152446
#           1957    25   386953916
#           1962    25   433270254
#           1967    25   480746623
#           1972    25   529384210
#           1977    25   578067699
#           1982    25   630290920
#           1987    25   682753971
#           1992    25   739274104
#           1997    25   796900410
#           2002    25   849772762
#           2007    25   898871184
# Asia      1952    33  1395357351
#           1957    33  1562780599
#           1962    33  1696357182
# ...

# %%
def func(x):
    print(x)
    return x['lifeExp'].mean() < 50

# %%
df.groupby('continent').filter(func)
# Out:
#        country continent  year  lifeExp  population    gdpPerCap
# 24     Algeria    Africa  1952   43.077     9279525  2449.008185
# 25     Algeria    Africa  1957   45.685    10270856  3013.976023
# 26     Algeria    Africa  1962   48.303    11000948  2550.816880
# 27     Algeria    Africa  1967   51.407    12760499  3246.991771
# 28     Algeria    Africa  1972   54.518    14760787  4182.663766
# ...        ...       ...   ...      ...         ...          ...
# 1699  Zimbabwe    Africa  1987   62.351     9216418   706.157306
# 1700  Zimbabwe    Africa  1992   60.377    10704340   693.420786
# 1701  Zimbabwe    Africa  1997   46.809    11404948   792.449960
# 1702  Zimbabwe    Africa  2002   39.989    11926563   672.038623
# 1703  Zimbabwe    Africa  2007   43.487    12311143   469.709298
#
# [624 rows x 6 columns]
#         country continent  year  lifeExp  population     gdpPerCap
# 48    Argentina  Americas  1952   62.485    17876956   5911.315053
# ...

# %%
len('Afghanistan')
# Out:
# 11

# %% [markdown]
# ## Apply

# %%
def custom(x):
    return len(x)

# %%
df['country_len'] = df['country'].apply(custom)

# %%
df
# Out:
#           country continent  year  lifeExp  population   gdpPerCap  \
# 0     Afghanistan      Asia  1952   28.801     8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332     9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997    10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020    11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088    13079460  739.981106
# ...           ...       ...   ...      ...         ...         ...
# 1699     Zimbabwe    Africa  1987   62.351     9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377    10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809    11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989    11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487    12311143  469.709298
#
#       country_len
# 0              11
# 1              11
# 2              11
# 3              11
# 4              11
# ...           ...
# 1699            8
# ...

# %%
df[['lifeExp', 'gdpPerCap']]
# Out:
#       lifeExp   gdpPerCap
# 0      28.801  779.445314
# 1      30.332  820.853030
# 2      31.997  853.100710
# 3      34.020  836.197138
# 4      36.088  739.981106
# ...       ...         ...
# 1699   62.351  706.157306
# 1700   60.377  693.420786
# 1701   46.809  792.449960
# 1702   39.989  672.038623
# 1703   43.487  469.709298
#
# [1704 rows x 2 columns]

# %%
df[['lifeExp', 'gdpPerCap']].apply(np.sum, axis=0)
# Out:
# lifeExp      1.013444e+05
# gdpPerCap    1.229492e+07
# dtype: float64

# %%
df[['lifeExp', 'gdpPerCap']].apply(np.sum, axis=1)
# Out:
# 0       808.246315
# 1       851.185030
# 2       885.097710
# 3       870.217138
# 4       776.069106
#            ...
# 1699    768.508306
# 1700    753.797786
# 1701    839.258960
# 1702    712.027623
# 1703    513.196298
# Length: 1704, dtype: float64

# %% [markdown]
# # Handling of Missing Values

# %%
type(None)
# Out:
# NoneType

# %%
type(np.nan)
# Out:
# float

# %%
None == np.nan
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
pd.isna(np.nan)
# Out:
# True

# %%
ser = pd.Series([1, np.nan, 5, None])
ser
# Out:
# 0    1.0
# 1    NaN
# 2    5.0
# 3    NaN
# dtype: float64

# %%
pd.isna(ser).sum()
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      1704 non-null   object
#  1   continent    1704 non-null   object
#  2   year         1704 non-null   int64
#  3   lifeExp      1704 non-null   float64
#  4   population   1704 non-null   int64
#  5   gdpPerCap    1704 non-null   float64
#  6   country_len  1704 non-null   int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 93.3+ KB

# %%
pd.isna(df).sum()
# Out:
# country        0
# continent      0
# year           0
# lifeExp        0
# population     0
# gdpPerCap      0
# country_len    0
# dtype: int64

# %%
disease = pd.read_csv('disease.csv')
disease.shape
# Out:
# (122, 14)

# %%
disease.head(15)
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_Nigeria  Cases_Senegal  \
# 0   7/22/2014  122        2770.0            NaN            NaN            NaN
# 1   7/21/2014  121        2771.0            NaN            NaN            NaN
# 2   7/20/2014  120        2765.0         8165.0            NaN            NaN
# 3   7/19/2014  119           NaN         8156.0            NaN            NaN
# 4   7/18/2014  118        2730.0         8115.0            NaN            NaN
# 5   7/17/2014  117        2706.0         8018.0            NaN            NaN
# 6   7/16/2014  116        2695.0            NaN            NaN            NaN
# 7   7/15/2014  115        2630.0         7977.0            NaN            NaN
# 8   7/14/2014  114        2597.0            NaN            NaN            NaN
# 9   7/13/2014  113        2571.0         7862.0            NaN            NaN
# 10  7/12/2014  112           NaN         7830.0            NaN            NaN
# ...

# %%
disease.isna().sum()
# Out:
# Date                      0
# Day                       0
# Cases_Guinea             29
# Cases_Liberia            39
# Cases_Nigeria            84
# Cases_Senegal            97
# Cases_UnitedKingdom     104
# Cases_Mali              110
# Deaths_Guinea            30
# Deaths_Liberia           41
# Deaths_Nigeria           84
# Deaths_Senegal          100
# Deaths_UnitedKingdom    104
# Deaths_Mali             110
# dtype: int64

# %%
disease.drop(columns='Deaths_Mali', inplace = True)

# %%
disease.head()
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_Nigeria  Cases_Senegal  \
# 0  7/22/2014  122        2770.0            NaN            NaN            NaN
# 1  7/21/2014  121        2771.0            NaN            NaN            NaN
# 2  7/20/2014  120        2765.0         8165.0            NaN            NaN
# 3  7/19/2014  119           NaN         8156.0            NaN            NaN
# 4  7/18/2014  118        2730.0         8115.0            NaN            NaN
#
#    Cases_UnitedKingdom  Cases_Mali  Deaths_Guinea  Deaths_Liberia  \
# 0                  NaN         NaN         1786.0             NaN
# 1                  NaN         NaN         1781.0             NaN
# 2                  NaN         NaN         1767.0          3496.0
# 3                  NaN         NaN            NaN          3496.0
# 4                  NaN         NaN         1739.0          3471.0
#
#    Deaths_Nigeria  Deaths_Senegal  Deaths_UnitedKingdom
# ...

# %%
disease.dropna(axis=1, thresh=50)
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Deaths_Guinea  \
# 0    7/22/2014  122        2770.0            NaN         1786.0
# 1    7/21/2014  121        2771.0            NaN         1781.0
# 2    7/20/2014  120        2765.0         8165.0         1767.0
# 3    7/19/2014  119           NaN         8156.0            NaN
# 4    7/18/2014  118        2730.0         8115.0         1739.0
# ..         ...  ...           ...            ...            ...
# 117  3/27/2014    5         103.0            8.0           66.0
# 118  3/26/2014    4          86.0            NaN           62.0
# 119  3/25/2014    3          86.0            NaN           60.0
# 120  3/24/2014    2          86.0            NaN           59.0
# 121  3/23/2014    1          49.0            NaN           29.0
#
#      Deaths_Liberia
# 0               NaN
# 1               NaN
# 2            3496.0
# 3            3496.0
# 4            3471.0
# ..              ...
# 117             6.0
# 118             NaN
# ...

# %%
disease['Deaths_Guinea'].fillna(value=-1,)
# Out:
# 0      1786.0
# 1      1781.0
# 2      1767.0
# 3        -1.0
# 4      1739.0
#         ...
# 117      66.0
# 118      62.0
# 119      60.0
# 120      59.0
# 121      29.0
# Name: Deaths_Guinea, Length: 122, dtype: float64

# %%
m= disease['Deaths_Guinea'].mean()
m
# Out:
# 563.2391304347826

# %%
disease['Deaths_Guinea'].fillna(value=m)
# Out:
# 0      1786.00000
# 1      1781.00000
# 2      1767.00000
# 3       563.23913
# 4      1739.00000
#           ...
# 117      66.00000
# 118      62.00000
# 119      60.00000
# 120      59.00000
# 121      29.00000
# Name: Deaths_Guinea, Length: 122, dtype: float64

# %%
disease['Deaths_Guinea']
# Out:
# 0      1786.0
# 1      1781.0
# 2      1767.0
# 3         NaN
# 4      1739.0
#         ...
# 117      66.0
# 118      62.0
# 119      60.0
# 120      59.0
# 121      29.0
# Name: Deaths_Guinea, Length: 122, dtype: float64

# %%
disease['Deaths_Guinea'].fillna(method='bfill')
# Out:
# 0      1786.0
# 1      1781.0
# 2      1767.0
# 3      1739.0
# 4      1739.0
#         ...
# 117      66.0
# 118      62.0
# 119      60.0
# 120      59.0
# 121      29.0
# Name: Deaths_Guinea, Length: 122, dtype: float64

# %%
disease['Deaths_Guinea'].fillna(method='ffill')

# %%
disease['Deaths_Guinea'].replace(to_replace=np.nan, value = m)
# Out:
# 0      1786.00000
# 1      1781.00000
# 2      1767.00000
# 3       563.23913
# 4      1739.00000
#           ...
# 117      66.00000
# 118      62.00000
# 119      60.00000
# 120      59.00000
# 121      29.00000
# Name: Deaths_Guinea, Length: 122, dtype: float64

# %%
disease.fillna(method='ffill', inplace=True)
disease.fillna(method='bfill', inplace=True)

# %%
disease
# Out:
#           Date  Day  Cases_Guinea  Cases_Liberia  Cases_Nigeria  \
# 0    7/22/2014  122        2770.0         8165.0           20.0
# 1    7/21/2014  121        2771.0         8165.0           20.0
# 2    7/20/2014  120        2765.0         8165.0           20.0
# 3    7/19/2014  119        2765.0         8156.0           20.0
# 4    7/18/2014  118        2730.0         8115.0           20.0
# ..         ...  ...           ...            ...            ...
# 117  3/27/2014    5         103.0            8.0            0.0
# 118  3/26/2014    4          86.0            8.0            0.0
# 119  3/25/2014    3          86.0            8.0            0.0
# 120  3/24/2014    2          86.0            8.0            0.0
# 121  3/23/2014    1          49.0            8.0            0.0
#
#      Cases_Senegal  Cases_UnitedKingdom  Cases_Mali  Deaths_Guinea  \
# 0              1.0                  4.0         7.0         1786.0
# ...
