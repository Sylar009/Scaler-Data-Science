# %%
import numpy as np
import pandas as pd

# %%
weather = pd.read_csv("weather.csv")
weather.head()
# Out:
#    year  month element       day1       day2       day3       day4       day5  \
# 0  2018      1     max  17.573016  19.796815  22.412495  17.813163  20.165825
# 1  2018      1     min  22.725760  21.007865  17.730792  18.045290  20.766734
# 2  2018      2     max  19.015120  19.261805  17.510713  21.080425  17.915749
# 3  2018      2     min  18.653843  22.818600  21.842673  21.958159  22.523078
# 4  2018      3     max  20.741115  19.704016  17.039811  20.703908  22.714125
#
#         day6       day7  ...      day22      day23      day24      day25  \
# 0  17.060539  22.736134  ...  22.629226  19.013674  17.831558  17.018316
# 1  18.656651  22.607481  ...  21.163491  17.371653  17.194530  18.964190
# 2  19.082145  18.056023  ...  21.254968  20.346324  20.036019  22.926773
# 3  18.535469  19.636158  ...  19.711974  20.586232  18.780840  20.065633
# 4  17.205000  19.079503  ...  19.528963  19.563689  22.658997  22.446357
#
#        day26      day27      day28      day29      day30      day31
# 0  21.837387  19.700255  19.084056  18.534690  20.787275  21.117423
# 1  17.892385  17.646139  19.844125  22.729859  19.768917  20.913443
# 2  17.533172  20.308927  20.438899  17.005806  18.346534  20.878165
# 3  18.293548  20.823661  18.056112  22.748292  22.470172  18.602007
# 4  17.911240  22.591993  17.406800  19.118712  22.767154  17.119452
#
# [5 rows x 34 columns]

# %%
weather.shape
# Out:
# (22, 34)

# %%
pd.melt(weather, ['year', 'month', 'element']).head()
# Out:
#    year  month element variable      value
# 0  2018      1     max     day1  17.573016
# 1  2018      1     min     day1  22.725760
# 2  2018      2     max     day1  19.015120
# 3  2018      2     min     day1  18.653843
# 4  2018      3     max     day1  20.741115

# %%
weather_melt = pd.melt(weather, 
                       id_vars = ['year', 'month', 'element'], 
                       var_name= 'day', 
                       value_name='temp')

weather_melt.head()
# Out:
#    year  month element   day       temp
# 0  2018      1     max  day1  17.573016
# 1  2018      1     min  day1  22.725760
# 2  2018      2     max  day1  19.015120
# 3  2018      2     min  day1  18.653843
# 4  2018      3     max  day1  20.741115

# %%
weather_melt.shape
# Out:
# (682, 5)

# %%
weather_melt.head()
# Out:
#    year  month element   day       temp
# 0  2018      1     max  day1  17.573016
# 1  2018      1     min  day1  22.725760
# 2  2018      2     max  day1  19.015120
# 3  2018      2     min  day1  18.653843
# 4  2018      3     max  day1  20.741115

# %%
weather_tidy = pd.pivot_table(weather_melt, 
                              index=['year' , 'month', 'day'], 
                              columns=['element'], 
                              values='temp', dropna=False)
weather_tidy
# Out:
# element                 max        min
# year month day
# 2018 1     day1   17.573016  22.725760
#            day10  19.067288  19.931129
#            day11  19.361002  22.598325
#            day12  20.982134  17.715137
#            day13  21.668005  17.940334
# ...                     ...        ...
#      12    day5   21.375349  20.865535
#            day6   17.992885  20.310116
#            day7   19.683359  20.531823
#            day8   20.477046  19.310346
#            day9   20.210640  22.820992
#
# [341 rows x 2 columns]

# %%
weather_tidy.loc[(2018, 1, 'day11')]
# Out:
# element
# max    19.361002
# min    22.598325
# Name: (2018, 1, day11), dtype: float64

# %%
weather_tidy.iloc[2, :]
# Out:
# element
# max    19.361002
# min    22.598325
# Name: (2018, 1, day11), dtype: float64

# %%
weather_tidy = weather_tidy.reset_index()
weather_tidy
# Out:
# element  year  month    day        max        min
# 0        2018      1   day1  17.573016  22.725760
# 1        2018      1  day10  19.067288  19.931129
# 2        2018      1  day11  19.361002  22.598325
# 3        2018      1  day12  20.982134  17.715137
# 4        2018      1  day13  21.668005  17.940334
# ..        ...    ...    ...        ...        ...
# 336      2018     12   day5  21.375349  20.865535
# 337      2018     12   day6  17.992885  20.310116
# 338      2018     12   day7  19.683359  20.531823
# 339      2018     12   day8  20.477046  19.310346
# 340      2018     12   day9  20.210640  22.820992
#
# [341 rows x 5 columns]

# %%
weather_tidy['day'].apply(lambda x : x[3:])
# Out:
# 0       1
# 1      10
# 2      11
# 3      12
# 4      13
#        ..
# 336     5
# 337     6
# 338     7
# 339     8
# 340     9
# Name: day, Length: 341, dtype: object

# %%
weather_tidy['day'] =  weather_tidy['day'].apply(lambda x : x.split('day')[-1], )

# %%
weather_tidy
# Out:
# element  year  month day        max        min
# 0        2018      1   1  17.573016  22.725760
# 1        2018      1  10  19.067288  19.931129
# 2        2018      1  11  19.361002  22.598325
# 3        2018      1  12  20.982134  17.715137
# 4        2018      1  13  21.668005  17.940334
# ..        ...    ...  ..        ...        ...
# 336      2018     12   5  21.375349  20.865535
# 337      2018     12   6  17.992885  20.310116
# 338      2018     12   7  19.683359  20.531823
# 339      2018     12   8  20.477046  19.310346
# 340      2018     12   9  20.210640  22.820992
#
# [341 rows x 5 columns]

# %%
flights = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/flights.csv')
flights.shape
# Out:
# (144, 3)

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
a = pd.pivot_table(flights, index=['year'], columns=['month'], values='passengers', dropna=False).reset_index()
a
# Out:
# month  year  April  August  December  February  January   July   June  March  \
# 0      1949  129.0   148.0     118.0     118.0    112.0  148.0  135.0  132.0
# 1      1950  135.0   170.0     140.0     126.0    115.0  170.0  149.0  141.0
# 2      1951  163.0   199.0     166.0     150.0    145.0  199.0  178.0  178.0
# 3      1952  181.0   242.0     194.0     180.0    171.0  230.0  218.0  193.0
# 4      1953  235.0   272.0     201.0     196.0    196.0  264.0  243.0  236.0
# 5      1954  227.0   293.0     229.0     188.0    204.0  302.0  264.0  235.0
# 6      1955  269.0   347.0     278.0     233.0    242.0  364.0  315.0  267.0
# 7      1956  313.0   405.0     306.0     277.0    284.0  413.0  374.0  317.0
# 8      1957  348.0   467.0     336.0     301.0    315.0  465.0  422.0  356.0
# 9      1958  348.0   505.0     337.0     318.0    340.0  491.0  435.0  362.0
# 10     1959  396.0   559.0     405.0     342.0    360.0  548.0  472.0  406.0
# 11     1960  461.0   606.0     432.0     391.0    417.0  622.0  535.0  419.0
#
# month    May  November  October  September
# 0      121.0     104.0    119.0      136.0
# 1      125.0     114.0    133.0      158.0
# 2      172.0     146.0    162.0      184.0
# 3      183.0     172.0    191.0      209.0
# 4      229.0     180.0    211.0      237.0
# 5      234.0     203.0    229.0      259.0
# 6      270.0     237.0    274.0      312.0
# 7      318.0     271.0    306.0      355.0
# 8      355.0     305.0    347.0      404.0
# 9      363.0     310.0    359.0      404.0
# 10     420.0     362.0    407.0      463.0
# 11     472.0     390.0    461.0      508.0

# %%
a
# Out:
# month  year  April  August  December  February  January   July   June  March  \
# 0      1949  129.0   148.0     118.0     118.0    112.0  148.0  135.0  132.0
# 1      1950  135.0   170.0     140.0     126.0    115.0  170.0  149.0  141.0
# 2      1951  163.0   199.0     166.0     150.0    145.0  199.0  178.0  178.0
# 3      1952  181.0   242.0     194.0     180.0    171.0  230.0  218.0  193.0
# 4      1953  235.0   272.0     201.0     196.0    196.0  264.0  243.0  236.0
# 5      1954  227.0   293.0     229.0     188.0    204.0  302.0  264.0  235.0
# 6      1955  269.0   347.0     278.0     233.0    242.0  364.0  315.0  267.0
# 7      1956  313.0   405.0     306.0     277.0    284.0  413.0  374.0  317.0
# 8      1957  348.0   467.0     336.0     301.0    315.0  465.0  422.0  356.0
# 9      1958  348.0   505.0     337.0     318.0    340.0  491.0  435.0  362.0
# 10     1959  396.0   559.0     405.0     342.0    360.0  548.0  472.0  406.0
# 11     1960  461.0   606.0     432.0     391.0    417.0  622.0  535.0  419.0
#
# month    May  November  October  September
# 0      121.0     104.0    119.0      136.0
# 1      125.0     114.0    133.0      158.0
# 2      172.0     146.0    162.0      184.0
# 3      183.0     172.0    191.0      209.0
# 4      229.0     180.0    211.0      237.0
# 5      234.0     203.0    229.0      259.0
# 6      270.0     237.0    274.0      312.0
# 7      318.0     271.0    306.0      355.0
# 8      355.0     305.0    347.0      404.0
# 9      363.0     310.0    359.0      404.0
# 10     420.0     362.0    407.0      463.0
# 11     472.0     390.0    461.0      508.0

# %%
a = pd.melt(a, id_vars=['year'], var_name='MONTH', value_name='PASSANGER')
a
# Out:
#      year      MONTH  PASSANGER
# 0    1949      April      129.0
# 1    1950      April      135.0
# 2    1951      April      163.0
# 3    1952      April      181.0
# 4    1953      April      235.0
# ..    ...        ...        ...
# 139  1956  September      355.0
# 140  1957  September      404.0
# 141  1958  September      404.0
# 142  1959  September      463.0
# 143  1960  September      508.0
#
# [144 rows x 3 columns]

# %%
a.sort_values('PASSANGER')
# Out:
#      year     MONTH  PASSANGER
# 108  1949  November      104.0
# 48   1949   January      112.0
# 109  1950  November      114.0
# 49   1950   January      115.0
# 36   1949  February      118.0
# ..    ...       ...        ...
# 83   1960      June      535.0
# 70   1959      July      548.0
# 22   1959    August      559.0
# 23   1960    August      606.0
# 71   1960      July      622.0
#
# [144 rows x 3 columns]

# %%
weather_tidy.head()
# Out:
# element  year  month day        max        min
# 0        2018      1   1  17.573016  22.725760
# 1        2018      1  10  19.067288  19.931129
# 2        2018      1  11  19.361002  22.598325
# 3        2018      1  12  20.982134  17.715137
# 4        2018      1  13  21.668005  17.940334

# %%
pd.cut(weather_tidy['max'], bins =5)
# Out:
# 0       (16.996, 18.19]
# 1       (18.19, 19.377]
# 2       (18.19, 19.377]
# 3      (20.565, 21.753]
# 4      (20.565, 21.753]
#              ...
# 336    (20.565, 21.753]
# 337     (16.996, 18.19]
# 338    (19.377, 20.565]
# 339    (19.377, 20.565]
# 340    (19.377, 20.565]
# Name: max, Length: 341, dtype: category
# Categories (5, interval[float64, right]): [(16.996, 18.19] < (18.19, 19.377] < (19.377, 20.565] < (20.565, 21.753] < (21.753, 22.94]]

# %%
pd.cut(weather_tidy['max'], bins =[10, 13, 15, 19, 24, 30], ).value_counts()
# Out:
# max
# (19, 24]    245
# (15, 19]     96
# (10, 13]      0
# (13, 15]      0
# (24, 30]      0
# Name: count, dtype: int64

# %%
weather_tidy['max_bucket'] = pd.cut(weather_tidy['max'], bins =[10, 13, 15, 19, 24, 30, 1000])

# %%
weather_tidy
# Out:
# element  year  month day        max        min max_bucket
# 0        2018      1   1  17.573016  22.725760   (15, 19]
# 1        2018      1  10  19.067288  19.931129   (19, 24]
# 2        2018      1  11  19.361002  22.598325   (19, 24]
# 3        2018      1  12  20.982134  17.715137   (19, 24]
# 4        2018      1  13  21.668005  17.940334   (19, 24]
# ..        ...    ...  ..        ...        ...        ...
# 336      2018     12   5  21.375349  20.865535   (19, 24]
# 337      2018     12   6  17.992885  20.310116   (15, 19]
# 338      2018     12   7  19.683359  20.531823   (19, 24]
# 339      2018     12   8  20.477046  19.310346   (19, 24]
# 340      2018     12   9  20.210640  22.820992   (19, 24]
#
# [341 rows x 6 columns]

# %% [markdown]
# ## write a .csv

# %%
weather_tidy.to_csv('result.csv', index=False)

# %%
pd.read_csv('result.csv')
# Out:
#      year  month  day        max        min max_bucket
# 0    2018      1    1  17.573016  22.725760   (15, 19]
# 1    2018      1   10  19.067288  19.931129   (19, 24]
# 2    2018      1   11  19.361002  22.598325   (19, 24]
# 3    2018      1   12  20.982134  17.715137   (19, 24]
# 4    2018      1   13  21.668005  17.940334   (19, 24]
# ..    ...    ...  ...        ...        ...        ...
# 336  2018     12    5  21.375349  20.865535   (19, 24]
# 337  2018     12    6  17.992885  20.310116   (15, 19]
# 338  2018     12    7  19.683359  20.531823   (19, 24]
# 339  2018     12    8  20.477046  19.310346   (19, 24]
# 340  2018     12    9  20.210640  22.820992   (19, 24]
#
# [341 rows x 6 columns]

# %% [markdown]
# # Uber Trip Analysis

# %%
data = pd.read_csv("UberData.csv")
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.shape
# Out:
# (1156, 7)

# %%
data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
data.drop(1155, inplace = True)

# %%
data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*
# 1150           Kar?chi     0.7         Meeting
# 1151  Unknown Location     3.9  Temporary Site
# 1152  Unknown Location    16.2         Meeting
# 1153           Gampaha     6.4  Temporary Site
# 1154         Ilukwatta    48.2  Temporary Site

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1155 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data.isna().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
data.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
# data.columns = ['START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP', 'MILES','PURPOSE']

# %%
data.columns = [x.replace("*", '') for x in data.columns]

# %%
data.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
# data.columns = list(map(lambda x : x[:-1], data.columns))

# %%
data['STOP'].str.len()
# Out:
# 0       11
# 1       11
# 2       11
# 3       11
# 4       15
#         ..
# 1150     7
# 1151    16
# 1152    16
# 1153     7
# 1154     9
# Name: STOP, Length: 1155, dtype: int64

# %%
data['STOP'].str.upper()
# Out:
# 0            FORT PIERCE
# 1            FORT PIERCE
# 2            FORT PIERCE
# 3            FORT PIERCE
# 4        WEST PALM BEACH
#               ...
# 1150             KAR?CHI
# 1151    UNKNOWN LOCATION
# 1152    UNKNOWN LOCATION
# 1153             GAMPAHA
# 1154           ILUKWATTA
# Name: STOP, Length: 1155, dtype: object

# %%
data['STOP'].str.split()
# Out:
# 0            [Fort, Pierce]
# 1            [Fort, Pierce]
# 2            [Fort, Pierce]
# 3            [Fort, Pierce]
# 4       [West, Palm, Beach]
#                ...
# 1150              [Kar?chi]
# 1151    [Unknown, Location]
# 1152    [Unknown, Location]
# 1153              [Gampaha]
# 1154            [Ilukwatta]
# Name: STOP, Length: 1155, dtype: object

# %%
data['STOP'].apply(lambda x: len(x))
# Out:
# 0       11
# 1       11
# 2       11
# 3       11
# 4       15
#         ..
# 1150     7
# 1151    16
# 1152    16
# 1153     7
# 1154     9
# Name: STOP, Length: 1155, dtype: int64

# %%
data.head()
# Out:
#        START_DATE        END_DATE  CATEGORY        START             STOP  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data['START_DATE'][0]
# Out:
# '1/1/2016 21:11'

# %%
data['START_DATE'] = pd.to_datetime(data['START_DATE'])
data['END_DATE'] = pd.to_datetime(data['END_DATE'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1155 non-null   datetime64[ns]
#  1   END_DATE    1155 non-null   datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1155 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
# datetime.strptime(date_of_execution,"%Y-%m-%d")

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE
# 0      Fort Pierce    5.1   Meal/Entertain
# 1      Fort Pierce    5.0              NaN
# 2      Fort Pierce    4.8  Errand/Supplies
# 3      Fort Pierce    4.7          Meeting
# 4  West Palm Beach   63.7   Customer Visit

# %%
ts = data['START_DATE'][1]
ts
# Out:
# Timestamp('2016-01-02 01:25:00')

# %%
ts.year
# Out:
# 2016

# %%
ts.month
# Out:
# 1

# %%
ts.day
# Out:
# 2

# %%
ts.month_name()
# Out:
# 'January'

# %%
ts.day_name()
# Out:
# 'Saturday'

# %%
ts.weekday()
# Out:
# 5

# %%
ts.hour
# Out:
# 1

# %%
ts.minute
# Out:
# 25

# %%
data['START_DATE'].apply(lambda x : x.year)
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2016
# 4       2016
#         ...
# 1150    2016
# 1151    2016
# 1152    2016
# 1153    2016
# 1154    2016
# Name: START_DATE, Length: 1155, dtype: int64

# %%
data['year'] = data['START_DATE'].dt.year

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year
# 0      Fort Pierce    5.1   Meal/Entertain  2016
# 1      Fort Pierce    5.0              NaN  2016
# 2      Fort Pierce    4.8  Errand/Supplies  2016
# 3      Fort Pierce    4.7          Meeting  2016
# 4  West Palm Beach   63.7   Customer Visit  2016

# %%
data.describe()
# Out:
#                           START_DATE                       END_DATE  \
# count                           1155                           1155
# mean   2016-07-16 23:44:33.402597376  2016-07-17 00:07:47.999999744
# min              2016-01-01 21:11:00            2016-01-01 21:17:00
# 25%              2016-04-01 02:10:00            2016-04-01 02:35:00
# 50%              2016-07-21 17:17:00            2016-07-21 17:23:00
# 75%              2016-10-27 21:06:30            2016-10-27 21:21:00
# max              2016-12-31 22:08:00            2016-12-31 23:51:00
# std                              NaN                            NaN
#
#              MILES    year
# count  1155.000000  1155.0
# mean     10.566840  2016.0
# min       0.500000  2016.0
# 25%       2.900000  2016.0
# 50%       6.000000  2016.0
# 75%      10.400000  2016.0
# max     310.300000  2016.0
# std      21.579106     0.0

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year
# 0      Fort Pierce    5.1   Meal/Entertain  2016
# 1      Fort Pierce    5.0              NaN  2016
# 2      Fort Pierce    4.8  Errand/Supplies  2016
# 3      Fort Pierce    4.7          Meeting  2016
# 4  West Palm Beach   63.7   Customer Visit  2016

# %%
data['MILES'].mean()
# Out:
# 10.566839826839827

# %%
data['MONTH'] = data['START_DATE'].dt.month_name()

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year    MONTH
# 0      Fort Pierce    5.1   Meal/Entertain  2016  January
# 1      Fort Pierce    5.0              NaN  2016  January
# 2      Fort Pierce    4.8  Errand/Supplies  2016  January
# 3      Fort Pierce    4.7          Meeting  2016  January
# 4  West Palm Beach   63.7   Customer Visit  2016  January

# %%
data['MONTH'].value_counts()
# Out:
# MONTH
# December     146
# August       133
# November     122
# February     115
# March        113
# July         112
# June         108
# October      106
# January       61
# April         54
# May           49
# September     36
# Name: count, dtype: int64

# %%
gb = data.groupby(by='MONTH')
gb.sum(True).sort_values('MILES', ascending=False)['MILES']
# Out:
# MONTH
# October      1810.0
# March        1693.9
# August       1335.5
# July         1224.6
# April        1113.0
# December      981.3
# February      908.2
# June          842.8
# November      816.9
# September     601.8
# January       512.9
# May           363.8
# Name: MILES, dtype: float64

# %%
# gb.get_group('January')

# %%
data[data['MILES']>200]
# Out:
#              START_DATE            END_DATE  CATEGORY         START  \
# 269 2016-03-25 16:52:00 2016-03-25 22:22:00  Business         Latta
# 270 2016-03-25 22:54:00 2016-03-26 01:39:00  Business  Jacksonville
#
#              STOP  MILES         PURPOSE  year  MONTH
# 269  Jacksonville  310.3  Customer Visit  2016  March
# 270     Kissimmee  201.0         Meeting  2016  March

# %%
data[data['MILES']< 1].head()
# Out:
#              START_DATE            END_DATE  CATEGORY                  START  \
# 7   2016-01-07 13:27:00 2016-01-07 13:33:00  Business                   Cary
# 44  2016-01-26 17:27:00 2016-01-26 17:29:00  Business                   Cary
# 120 2016-02-17 16:38:00 2016-02-17 16:43:00  Business             Katunayaka
# 189 2016-03-04 16:16:00 2016-03-04 16:22:00  Business    Fayetteville Street
# 212 2016-03-11 10:29:00 2016-03-11 10:36:00  Business  Congress Ave District
#
#                         STOP  MILES          PURPOSE  year     MONTH
# 7                       Cary    0.8          Meeting  2016   January
# 44                      Cary    0.5  Errand/Supplies  2016   January
# 120               Katunayaka    0.5  Errand/Supplies  2016  February
# 189  Depot Historic District    0.8  Errand/Supplies  2016     March
# 212                 Downtown    0.8              NaN  2016     March

# %%
data['KMs']= data['MILES']*1.609

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year    MONTH       KMs
# 0      Fort Pierce    5.1   Meal/Entertain  2016  January    8.2059
# 1      Fort Pierce    5.0              NaN  2016  January    8.0450
# 2      Fort Pierce    4.8  Errand/Supplies  2016  January    7.7232
# 3      Fort Pierce    4.7          Meeting  2016  January    7.5623
# 4  West Palm Beach   63.7   Customer Visit  2016  January  102.4933

# %%
data['HOUR'] = data['START_DATE'].dt.hour

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year    MONTH       KMs  HOUR
# 0      Fort Pierce    5.1   Meal/Entertain  2016  January    8.2059    21
# 1      Fort Pierce    5.0              NaN  2016  January    8.0450     1
# 2      Fort Pierce    4.8  Errand/Supplies  2016  January    7.7232    20
# 3      Fort Pierce    4.7          Meeting  2016  January    7.5623    17
# 4  West Palm Beach   63.7   Customer Visit  2016  January  102.4933    14

# %%
data['HOUR'].value_counts()
# Out:
# HOUR
# 15    98
# 17    95
# 13    94
# 18    94
# 14    89
# 16    88
# 12    77
# 11    72
# 20    71
# 19    68
# 10    65
# 9     51
# 21    51
# 8     35
# 22    31
# 23    26
# 0     19
# 7     13
# 1      5
# 5      4
# 6      4
# 3      3
# 2      2
# Name: count, dtype: int64

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year    MONTH       KMs  HOUR
# 0      Fort Pierce    5.1   Meal/Entertain  2016  January    8.2059    21
# 1      Fort Pierce    5.0              NaN  2016  January    8.0450     1
# 2      Fort Pierce    4.8  Errand/Supplies  2016  January    7.7232    20
# 3      Fort Pierce    4.7          Meeting  2016  January    7.5623    17
# 4  West Palm Beach   63.7   Customer Visit  2016  January  102.4933    14

# %%
def convertToMinutes(time):
    return time.seconds/60

# %%
data['DURATION_MINS'] = (data['END_DATE'] - data['START_DATE']).apply(convertToMinutes)

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year    MONTH       KMs  HOUR  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016  January    8.2059    21
# 1      Fort Pierce    5.0              NaN  2016  January    8.0450     1
# 2      Fort Pierce    4.8  Errand/Supplies  2016  January    7.7232    20
# 3      Fort Pierce    4.7          Meeting  2016  January    7.5623    17
# 4  West Palm Beach   63.7   Customer Visit  2016  January  102.4933    14
#
#    DURATION_MINS
# 0            6.0
# 1           12.0
# 2           13.0
# 3           14.0
# 4           67.0

# %%
data['SPEED_KMPH']= (data['KMs']/(data['DURATION_MINS']/60)).round(1)

# %%
data.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE  year    MONTH       KMs  HOUR  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016  January    8.2059    21
# 1      Fort Pierce    5.0              NaN  2016  January    8.0450     1
# 2      Fort Pierce    4.8  Errand/Supplies  2016  January    7.7232    20
# 3      Fort Pierce    4.7          Meeting  2016  January    7.5623    17
# 4  West Palm Beach   63.7   Customer Visit  2016  January  102.4933    14
#
#    DURATION_MINS  SPEED_KMPH
# 0            6.0        82.1
# 1           12.0        40.2
# 2           13.0        35.6
# 3           14.0        32.4
# 4           67.0        91.8

# %%
data['SPEED_KMPH'].mean()
# Out:
# inf

# %%
data[data['SPEED_KMPH'] > 10000]
# Out:
#              START_DATE            END_DATE  CATEGORY             START  \
# 751 2016-09-06 17:49:00 2016-09-06 17:49:00  Business  Unknown Location
# 761 2016-09-16 07:08:00 2016-09-16 07:08:00  Business  Unknown Location
# 798 2016-10-08 15:03:00 2016-10-08 15:03:00  Business           Karachi
# 807 2016-10-13 13:02:00 2016-10-13 13:02:00  Business         Islamabad
#
#                  STOP  MILES PURPOSE  year      MONTH       KMs  HOUR  \
# 751  Unknown Location   69.1     NaN  2016  September  111.1819    17
# 761  Unknown Location    1.6     NaN  2016  September    2.5744     7
# 798           Karachi    3.6     NaN  2016    October    5.7924    15
# 807         Islamabad    0.7     NaN  2016    October    1.1263    13
#
#      DURATION_MINS  SPEED_KMPH
# 751            0.0         inf
# 761            0.0         inf
# 798            0.0         inf
# 807            0.0         inf

# %%
data['PURPOSE'].value_counts(dropna=False)
# Out:
# PURPOSE
# NaN                502
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: count, dtype: int64

# %%
data['PURPOSE'].fillna('OTHER', inplace=True)
# Out:
# C:\Users\sanya\AppData\Local\Temp\ipykernel_9392\1289416610.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['PURPOSE'].fillna('OTHER', inplace=True)

# %%
data.isna().sum()
# Out:
# START_DATE       0
# END_DATE         0
# CATEGORY         0
# START            0
# STOP             0
# MILES            0
# PURPOSE          0
# year             0
# MONTH            0
# KMs              0
# HOUR             0
# DURATION_MINS    0
# SPEED_KMPH       0
# dtype: int64

# %%
data['KMs'].hist(bins=20)
# Out:
# <Axes: >
