# %% [markdown]
# # Netflix Project
#
# - The exploration should have a goal. As you explore the data, keep in mind that you want to answer which type of shows to produce and how to grow the business.
# - Ensure each recommendation is backed by data. The company is looking for data-driven insights, not personal opinions or anecdotes.
# - Assume that you are presenting your findings to business executives who have only a basic understanding of data science. Avoid unnecessary technical jargon.
# - Start by exploring a few questions: What type of content is available in different countries?
# - How has the number of movies released per year changed over the last 20-30 years?
# - Comparison of tv shows vs. movies.
# - What is the best time to launch a TV show?
# - Analysis of actors/directors of different types of shows/movies.

# %% [markdown]
# - Show_id: Unique ID for every Movie / Tv Show
# - Type: Identifier - A Movie or TV Show
# - Title: Title of the Movie / Tv Show
# - Director: Director of the Movie
# - Cast: Actors involved in the movie/show
# - Country: Country where the movie/show was produced
# - Date_added: Date it was added on Netflix
# - Release_year: Actual Release year of the movie/show
# - Rating: TV Rating of the movie/show
# - Duration: Total Duration - in minutes or number of seasons
# - Listed_in: Genre
# - Description: The summary description

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df['show_id'].nunique()
# Out:
# 8807

# %%
df['title'].nunique()
# Out:
# 8807

# %%
df.drop(columns='title',inplace=True)

# %%
df.head()
# Out:
#   show_id     type         director  \
# 0      s1    Movie  Kirsten Johnson
# 1      s2  TV Show              NaN
# 2      s3  TV Show  Julien Leclercq
# 3      s4  TV Show              NaN
# 4      s5  TV Show              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.drop(columns='description',inplace=True)
df.head()
# Out:
#   show_id     type         director  \
# 0      s1    Movie  Kirsten Johnson
# 1      s2  TV Show              NaN
# 2      s3  TV Show  Julien Leclercq
# 3      s4  TV Show              NaN
# 4      s5  TV Show              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df.head(10)
# Out:
#   show_id     type                       director  \
# 0      s1    Movie                Kirsten Johnson
# 1      s2  TV Show                            NaN
# 2      s3  TV Show                Julien Leclercq
# 3      s4  TV Show                            NaN
# 4      s5  TV Show                            NaN
# 5      s6  TV Show                  Mike Flanagan
# 6      s7    Movie  Robert Cullen, José Luis Ucha
# 7      s8    Movie                   Haile Gerima
# 8      s9  TV Show                Andy Devonshire
# 9     s10    Movie                 Theodore Melfi
#
#                                                 cast  \
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
#
#                                              country          date_added  \
# 0                                      United States  September 25, 2021
# 1                                       South Africa  September 24, 2021
# 2                                                NaN  September 24, 2021
# 3                                                NaN  September 24, 2021
# 4                                              India  September 24, 2021
# 5                                                NaN  September 24, 2021
# 6                                                NaN  September 24, 2021
# 7  United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# 8                                     United Kingdom  September 24, 2021
# 9                                      United States  September 24, 2021
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# 3          2021  TV-MA   1 Season
# 4          2021  TV-MA  2 Seasons
# 5          2021  TV-MA   1 Season
# 6          2021     PG     91 min
# 7          1993  TV-MA    125 min
# 8          2021  TV-14  9 Seasons
# 9          2021  PG-13    104 min
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
# 6                           Children & Family Movies
# 7   Dramas, Independent Movies, International Movies
# 8                       British TV Shows, Reality TV
# 9                                   Comedies, Dramas

# %%
df['cast'].isna().sum()
# Out:
# 825

# %%
df['cast'].replace(np.nan,'Others',inplace=True)
# Out:
# C:\Users\sanya\AppData\Local\Temp\ipykernel_12564\1245080248.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['cast'].replace(np.nan,'Others',inplace=True)

# %%
df['cast'].isna().sum()
# Out:
# 0

# %%
df['cast']=df['cast'].apply(lambda x : x.split(', '))

# %%
df['cast'][2]
# Out:
# ['Sami Bouajila',
#  'Tracy Gotoas',
#  'Samuel Jouy',
#  'Nabiha Akkari',
#  'Sofia Lesaffre',
#  'Salim Kechiouche',
#  'Noureddine Farihi',
#  'Geert Van Rampelberg',
#  'Bakary Diombera']

# %%
df.head()
# Out:
#   show_id     type         director  \
# 0      s1    Movie  Kirsten Johnson
# 1      s2  TV Show              NaN
# 2      s3  TV Show  Julien Leclercq
# 3      s4  TV Show              NaN
# 4      s5  TV Show              NaN
#
#                                                 cast        country  \
# 0                                           [Others]  United States
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...   South Africa
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...            NaN
# 3                                           [Others]            NaN
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %%
df[(df['director'].isna()) & (df['type']=='TV Show')]
# Out:
#      show_id     type director  \
# 1         s2  TV Show      NaN
# 3         s4  TV Show      NaN
# 4         s5  TV Show      NaN
# 10       s11  TV Show      NaN
# 14       s15  TV Show      NaN
# ...      ...      ...      ...
# 8795   s8796  TV Show      NaN
# 8796   s8797  TV Show      NaN
# 8797   s8798  TV Show      NaN
# 8800   s8801  TV Show      NaN
# 8803   s8804  TV Show      NaN
#
#                                                    cast  \
# 1     [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...
# 3                                              [Others]
# 4     [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...
# 10                                             [Others]
# 14                                             [Others]
# ...                                                 ...
# 8795  [Mike Liscio, Emily Bauer, Billy Bob Thompson,...
# 8796  [Gökhan Atalay, Payidar Tüfekçioglu, Baran Akb...
# 8797  [Michael Johnston, Jessica Gee-George, Christi...
# 8800  [Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen...
# 8803                                           [Others]
#
#                                             country          date_added  \
# 1                                      South Africa  September 24, 2021
# 3                                               NaN  September 24, 2021
# 4                                             India  September 24, 2021
# 10                                              NaN  September 24, 2021
# 14                                              NaN  September 22, 2021
# ...                                             ...                 ...
# 8795                                  Japan, Canada         May 1, 2018
# 8796                                         Turkey    January 17, 2017
# 8797  United States, France, South Korea, Indonesia  September 13, 2018
# 8800                                       Pakistan   December 15, 2016
# 8803                                            NaN        July 1, 2019
#
#       release_year rating   duration  \
# 1             2021  TV-MA  2 Seasons
# 3             2021  TV-MA   1 Season
# 4             2021  TV-MA  2 Seasons
# 10            2021  TV-MA   1 Season
# 14            2021  TV-MA   1 Season
# ...            ...    ...        ...
# 8795          2015  TV-Y7  2 Seasons
# 8796          2016  TV-PG  2 Seasons
# 8797          2016  TV-Y7  3 Seasons
# 8800          2012  TV-PG   1 Season
# 8803          2018  TV-Y7  2 Seasons
#
#                                               listed_in
# 1       International TV Shows, TV Dramas, TV Mysteries
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# 10    Crime TV Shows, Docuseries, International TV S...
# 14         British TV Shows, Crime TV Shows, Docuseries
# ...                                                 ...
# 8795                             Anime Series, Kids' TV
# 8796                  International TV Shows, TV Dramas
# 8797                                           Kids' TV
# 8800  International TV Shows, Romantic TV Shows, TV ...
# 8803             Kids' TV, Korean TV Shows, TV Comedies
#
# [2446 rows x 10 columns]

# %%
df[(df['director'].isna()) & (df['type']=='Movie')]
# Out:
#      show_id   type director  \
# 404     s405  Movie      NaN
# 470     s471  Movie      NaN
# 483     s484  Movie      NaN
# 641     s642  Movie      NaN
# 717     s718  Movie      NaN
# ...      ...    ...      ...
# 8231   s8232  Movie      NaN
# 8268   s8269  Movie      NaN
# 8330   s8331  Movie      NaN
# 8647   s8648  Movie      NaN
# 8784   s8785  Movie      NaN
#
#                                                    cast         country  \
# 404                                            [Others]             NaN
# 470      [David Spade, London Hughes, Fortune Feimster]             NaN
# 483   [Fatih Şahin, Ece Çeşmioğlu, Halit Özgür Sarı,...             NaN
# 641                                            [Others]             NaN
# 717   [Andy Puddicombe, Evelyn Lewis Prieto, Ginger ...             NaN
# ...                                                 ...             ...
# 8231                                     [Chow Yun Fat]       Hong Kong
# 8268                                           [Others]  United Kingdom
# 8330  [Zo In-sung, Nam Joo-hyuk, Park Sung-woong, Ba...     South Korea
# 8647  [Vijay Maurya, Naman Jain, Usha Nadkarni, Muke...           India
# 8784  [Eileen Stevens, Alyson Leigh Rosenfeld, Sarah...   Russia, Spain
#
#               date_added  release_year rating duration  \
# 404        July 22, 2021          2021  TV-MA   85 min
# 470        July 13, 2021          2021  TV-14   39 min
# 483         July 9, 2021          2021  TV-MA  102 min
# 641        June 24, 2021          2021     PG   97 min
# 717        June 15, 2021          2021   TV-G  273 min
# ...                  ...           ...    ...      ...
# 8231  September 20, 2018          1983  TV-14  103 min
# 8268       June 23, 2018          2016  TV-MA   75 min
# 8330       April 8, 2019          2018  TV-MA  136 min
# 8647    January 15, 2017          2015  TV-14   89 min
# 8784       June 23, 2018          2015   TV-Y   78 min
#
#                                               listed_in
# 404                                       Documentaries
# 470                                              Movies
# 483       Dramas, International Movies, Romantic Movies
# 641                        Documentaries, Sports Movies
# 717                                       Documentaries
# ...                                                 ...
# 8231   Action & Adventure, Dramas, International Movies
# 8268  Action & Adventure, Independent Movies, Intern...
# 8330   Action & Adventure, Dramas, International Movies
# 8647                       Dramas, International Movies
# 8784                           Children & Family Movies
#
# [188 rows x 10 columns]

# %%
df['director'].replace(np.nan,'No Director',inplace=True)
# Out:
# C:\Users\sanya\AppData\Local\Temp\ipykernel_12564\3606583013.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df
place=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df[df['rating'].isna()]
# Out:
#      show_id     type         director  \
# 5989   s5990    Movie      No Director
# 6827   s6828  TV Show      No Director
# 7312   s7313  TV Show      No Director
# 7537   s7538    Movie  Alessandro Pepe
#
#                                                    cast    country  \
# 5989                      [Oprah Winfrey, Ava DuVernay]        NaN
# 6827  [Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, K...      Japan
# 7312  [Flynn Curry, Olivia Deeble, Madison Lu, Oisín...  Australia
# 7537  [Leone Frisa, Paolo Vaccarino, Francesco Migli...      Italy
#
#             date_added  release_year rating  duration  \
# 5989  January 26, 2017          2017    NaN    37 min
# 6827  December 1, 2016          2013    NaN  1 Season
# 7312  February 1, 2018          2015    NaN  1 Season
# 7537     March 1, 2017          2015    NaN   115 min
#
#                                  listed_in
# 5989                                Movies
# 6827  Anime Series, International TV Shows
# 7312                 Kids' TV, TV Comedies
# 7537                                Dramas

# %%
df[df['listed_in'].str.contains("Kids' TV")]['rating'].value_counts()
# Out:
# rating
# TV-Y7       189
# TV-Y        176
# TV-G         43
# TV-PG        41
# TV-Y7-FV      1
# Name: count, dtype: int64

# %%
df.loc[7312,'rating']='TV-Y7'

# %%
df[df['rating'].isna()]
# Out:
#      show_id     type         director  \
# 5989   s5990    Movie      No Director
# 6827   s6828  TV Show      No Director
# 7537   s7538    Movie  Alessandro Pepe
#
#                                                    cast country  \
# 5989                      [Oprah Winfrey, Ava DuVernay]     NaN
# 6827  [Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, K...   Japan
# 7537  [Leone Frisa, Paolo Vaccarino, Francesco Migli...   Italy
#
#             date_added  release_year rating  duration  \
# 5989  January 26, 2017          2017    NaN    37 min
# 6827  December 1, 2016          2013    NaN  1 Season
# 7537     March 1, 2017          2015    NaN   115 min
#
#                                  listed_in
# 5989                                Movies
# 6827  Anime Series, International TV Shows
# 7537                                Dramas

# %%
df[df['listed_in'].str.contains("Movies")]['rating'].value_counts()
# Out:
# rating
# TV-MA       1459
# TV-14       1182
# R            451
# TV-PG        424
# PG           253
# PG-13        252
# TV-Y7        139
# TV-Y         131
# TV-G         104
# NR            54
# G             39
# TV-Y7-FV       5
# NC-17          3
# UR             2
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df.loc[5989,'rating']='TV-MA'

# %%
df[df['rating'].isna()]
# Out:
#      show_id     type         director  \
# 6827   s6828  TV Show      No Director
# 7537   s7538    Movie  Alessandro Pepe
#
#                                                    cast country  \
# 6827  [Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, K...   Japan
# 7537  [Leone Frisa, Paolo Vaccarino, Francesco Migli...   Italy
#
#             date_added  release_year rating  duration  \
# 6827  December 1, 2016          2013    NaN  1 Season
# 7537     March 1, 2017          2015    NaN   115 min
#
#                                  listed_in
# 6827  Anime Series, International TV Shows
# 7537                                Dramas

# %%
df[df['listed_in'].str.contains("Dramas")]['rating'].value_counts()
# Out:
# rating
# TV-MA    1264
# TV-14     962
# R         376
# TV-PG     249
# PG-13     192
# PG         69
# TV-G       36
# NR         28
# G           6
# TV-Y        3
# UR          2
# NC-17       1
# TV-Y7       1
# Name: count, dtype: int64

# %%
df.loc[7537,'rating']='TV-MA'

# %%
df[df['rating'].isna()]
# Out:
#      show_id     type     director  \
# 6827   s6828  TV Show  No Director
#
#                                                    cast country  \
# 6827  [Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, K...   Japan
#
#             date_added  release_year rating  duration  \
# 6827  December 1, 2016          2013    NaN  1 Season
#
#                                  listed_in
# 6827  Anime Series, International TV Shows

# %%
df[df['listed_in'].str.contains("Anime Series, International TV Shows")]['rating'].value_counts()
# Out:
# rating
# TV-14    57
# TV-MA    46
# TV-PG     9
# TV-Y7     2
# Name: count, dtype: int64

# %%
df.loc[6827,'rating']='TV-14'

# %%
df['rating'].isna().isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df[df['duration'].isna()]
# Out:
#      show_id   type    director          cast        country  \
# 5541   s5542  Movie  Louis C.K.  [Louis C.K.]  United States
# 5794   s5795  Movie  Louis C.K.  [Louis C.K.]  United States
# 5813   s5814  Movie  Louis C.K.  [Louis C.K.]  United States
#
#               date_added  release_year  rating duration listed_in
# 5541       April 4, 2017          2017  74 min      NaN    Movies
# 5794  September 16, 2016          2010  84 min      NaN    Movies
# 5813     August 15, 2016          2015  66 min      NaN    Movies

# %%
df[df['duration'].isna()]['rating']
# Out:
# 5541    74 min
# 5794    84 min
# 5813    66 min
# Name: rating, dtype: object

# %%
df.loc[df['duration'].isna(),'duration']=df[df['duration'].isna()]['rating']

# %%
df[df['duration'].isna()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, director, cast, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
df.loc[df['rating'].str.contains('min'),'rating']='TV-MA'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df.loc[df['country'].isna(),'country']='Country Not Mentioned'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df.head()
# Out:
#   show_id     type         director  \
# 0      s1    Movie  Kirsten Johnson
# 1      s2  TV Show      No Director
# 2      s3  TV Show  Julien Leclercq
# 3      s4  TV Show      No Director
# 4      s5  TV Show      No Director
#
#                                                 cast                country  \
# 0                                           [Others]          United States
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...           South Africa
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  Country Not Mentioned
# 3                                           [Others]  Country Not Mentioned
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...                  India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...

# %%
df['listed_in']=df['listed_in'].apply(lambda x : x.split(', '))

# %%
df['listed_in'][2]
# Out:
# ['Crime TV Shows', 'International TV Shows', 'TV Action & Adventure']

# %%
df.head()
# Out:
#   show_id     type         director  \
# 0      s1    Movie  Kirsten Johnson
# 1      s2  TV Show      No Director
# 2      s3  TV Show  Julien Leclercq
# 3      s4  TV Show      No Director
# 4      s5  TV Show      No Director
#
#                                                 cast                country  \
# 0                                           [Others]          United States
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...           South Africa
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  Country Not Mentioned
# 3                                           [Others]  Country Not Mentioned
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...                  India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [Crime TV Shows, International TV Shows, TV Ac...
# 3                           [Docuseries, Reality TV]
# 4  [International TV Shows, Romantic TV Shows, TV...

# %%
df[df['director'].apply(lambda x : True if ',' in x else False)]
# Out:
#      show_id   type                                           director  \
# 6         s7  Movie                      Robert Cullen, José Luis Ucha
# 16       s17  Movie      Pedro de Echave García, Pablo Azorín Williams
# 23       s24  Movie                            Alex Woo, Stanley Moore
# 30       s31  Movie  Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# 68       s69  Movie  Hanns-Bruno Kammertöns, Vanessa Nöcker, Michae...
# ...      ...    ...                                                ...
# 8727   s8728  Movie                          Ritu Sarin, Tenzing Sonam
# 8728   s8729  Movie                    Heidi Brandenburg, Mathew Orzel
# 8737   s8738  Movie             Milla Harrison-Hansley, Alicky Sussman
# 8739   s8740  Movie                        Frank Capra, Anatole Litvak
# 8765   s8766  Movie  Jovanka Vuckovic, Annie Clark, Roxanne Benjami...
#
#                                                    cast  \
# 6     [Vanessa Hudgens, Kimiko Glenn, James Marsden,...
# 16                                             [Others]
# 23    [Maisie Benson, Paul Killam, Kerry Gudjohnsen,...
# 30    [Abhishek Banerjee, Rinku Rajguru, Delzad Hiwa...
# 68                                 [Michael Schumacher]
# ...                                                 ...
# 8727                                           [Others]
# 8728                                           [Others]
# 8737                                        [Giles Yeo]
# 8739                                           [Others]
# 8765  [Natalie Brown, Jonathan Watton, Melanie Lynsk...
#
#                                    country          date_added  release_year  \
# 6                    Country Not Mentioned  September 24, 2021          2021
# 16                   Country Not Mentioned  September 22, 2021          2020
# 23                   Country Not Mentioned  September 21, 2021          2021
# 30                   Country Not Mentioned  September 17, 2021          2021
# 68                   Country Not Mentioned  September 15, 2021          2021
# ...                                    ...                 ...           ...
# 8727  United Kingdom, India, United States   December 25, 2016          2013
# 8728   Peru, United States, United Kingdom   November 30, 2016          2016
# 8737                        United Kingdom    February 1, 2019          2016
# 8739                         United States      March 31, 2017          1943
# 8765                 Canada, United States       June 22, 2017          2017
#
#      rating duration                                          listed_in
# 6        PG   91 min                         [Children & Family Movies]
# 16    TV-MA   67 min              [Documentaries, International Movies]
# 23     TV-Y   61 min                         [Children & Family Movies]
# 30    TV-14  111 min  [Dramas, Independent Movies, International Mov...
# 68    TV-14  113 min  [Documentaries, International Movies, Sports M...
# ...     ...      ...                                                ...
# 8727     NR   75 min              [Documentaries, International Movies]
# 8728  TV-14  103 min              [Documentaries, International Movies]
# 8737  TV-14   50 min                                    [Documentaries]
# 8739  TV-PG   82 min                                    [Documentaries]
# 8765      R   81 min                                    [Horror Movies]
#
# [614 rows x 10 columns]

# %%
df['director']=df['director'].apply(lambda x : x.split(', '))

# %%
df[df['director'].apply(lambda x : True if ',' in x else False)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, director, cast, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %%
df.head()
# Out:
#   show_id     type           director  \
# 0      s1    Movie  [Kirsten Johnson]
# 1      s2  TV Show      [No Director]
# 2      s3  TV Show  [Julien Leclercq]
# 3      s4  TV Show      [No Director]
# 4      s5  TV Show      [No Director]
#
#                                                 cast                country  \
# 0                                           [Others]          United States
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...           South Africa
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  Country Not Mentioned
# 3                                           [Others]  Country Not Mentioned
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...                  India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [Crime TV Shows, International TV Shows, TV Ac...
# 3                           [Docuseries, Reality TV]
# 4  [International TV Shows, Romantic TV Shows, TV...

# %%
def function(x):
    length=int(x.split()[0])
    if length<=30:
        return "0-30"
    elif length<=60:
        return "31-60"
    elif length<=90:
        return "61-90"
    elif length<=120:
        return "91-120"
    elif length<=150:
        return "121-150"
    elif length<=180:
        return "151-180"
    else:
        return "Above 180"

# %%
df.loc[df['type']=='Movie','duration'] = df.loc[df['type']=='Movie','duration'].apply(function)

# %%
df.loc[df['type']=='Movie','duration'].value_counts()
# Out:
# duration
# 91-120       2996
# 61-90        1506
# 121-150       897
# 31-60         357
# 151-180       198
# 0-30          130
# Above 180      47
# Name: count, dtype: int64

# %% [markdown]
# # Un-Nest

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   date_added    8807 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df.head()
# Out:
#   show_id     type           director  \
# 0      s1    Movie  [Kirsten Johnson]
# 1      s2  TV Show      [No Director]
# 2      s3  TV Show  [Julien Leclercq]
# 3      s4  TV Show      [No Director]
# 4      s5  TV Show      [No Director]
#
#                                                 cast                country  \
# 0                                           [Others]          United States
# 1  [Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...           South Africa
# 2  [Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...  Country Not Mentioned
# 3                                           [Others]  Country Not Mentioned
# 4  [Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...                  India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13      61-90
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in
# 0                                    [Documentaries]
# 1  [International TV Shows, TV Dramas, TV Mysteries]
# 2  [Crime TV Shows, International TV Shows, TV Ac...
# 3                           [Docuseries, Reality TV]
# 4  [International TV Shows, Romantic TV Shows, TV...

# %%
df.shape
# Out:
# (8807, 10)

# %%
constraint=df['cast'].tolist()
constraint
new_df = pd.DataFrame(constraint,index=df['show_id']) 
new_df.head()
cast_df = pd.DataFrame(new_df.stack(),columns=['Cast']).reset_index().iloc[:,[0,2]]
cast_df
# Out:
#       show_id                   Cast
# 0          s1                 Others
# 1          s2             Ama Qamata
# 2          s2            Khosi Ngema
# 3          s2          Gail Mabalane
# 4          s2         Thabang Molaba
# ...       ...                    ...
# 64946   s8807       Manish Chaudhary
# 64947   s8807           Meghna Malik
# 64948   s8807          Malkeet Rauni
# 64949   s8807         Anita Shabdish
# 64950   s8807  Chittaranjan Tripathy
#
# [64951 rows x 2 columns]

# %%
other_df=df[['show_id','type','country','date_added','release_year','rating','duration']]
other_df
# Out:
#      show_id     type                country          date_added  \
# 0         s1    Movie          United States  September 25, 2021
# 1         s2  TV Show           South Africa  September 24, 2021
# 2         s3  TV Show  Country Not Mentioned  September 24, 2021
# 3         s4  TV Show  Country Not Mentioned  September 24, 2021
# 4         s5  TV Show                  India  September 24, 2021
# ...      ...      ...                    ...                 ...
# 8802   s8803    Movie          United States   November 20, 2019
# 8803   s8804  TV Show  Country Not Mentioned        July 1, 2019
# 8804   s8805    Movie          United States    November 1, 2019
# 8805   s8806    Movie          United States    January 11, 2020
# 8806   s8807    Movie                  India       March 2, 2019
#
#       release_year rating   duration
# 0             2020  PG-13      61-90
# 1             2021  TV-MA  2 Seasons
# 2             2021  TV-MA   1 Season
# 3             2021  TV-MA   1 Season
# 4             2021  TV-MA  2 Seasons
# ...            ...    ...        ...
# 8802          2007      R    151-180
# 8803          2018  TV-Y7  2 Seasons
# 8804          2009      R      61-90
# 8805          2006     PG      61-90
# 8806          2015  TV-14     91-120
#
# [8807 rows x 7 columns]

# %%
df1=pd.merge(left=cast_df,right=other_df,on='show_id')
df1
# Out:
#       show_id                   Cast     type        country  \
# 0          s1                 Others    Movie  United States
# 1          s2             Ama Qamata  TV Show   South Africa
# 2          s2            Khosi Ngema  TV Show   South Africa
# 3          s2          Gail Mabalane  TV Show   South Africa
# 4          s2         Thabang Molaba  TV Show   South Africa
# ...       ...                    ...      ...            ...
# 64946   s8807       Manish Chaudhary    Movie          India
# 64947   s8807           Meghna Malik    Movie          India
# 64948   s8807          Malkeet Rauni    Movie          India
# 64949   s8807         Anita Shabdish    Movie          India
# 64950   s8807  Chittaranjan Tripathy    Movie          India
#
#                date_added  release_year rating   duration
# 0      September 25, 2021          2020  PG-13      61-90
# 1      September 24, 2021          2021  TV-MA  2 Seasons
# 2      September 24, 2021          2021  TV-MA  2 Seasons
# 3      September 24, 2021          2021  TV-MA  2 Seasons
# 4      September 24, 2021          2021  TV-MA  2 Seasons
# ...                   ...           ...    ...        ...
# 64946       March 2, 2019          2015  TV-14     91-120
# 64947       March 2, 2019          2015  TV-14     91-120
# 64948       March 2, 2019          2015  TV-14     91-120
# 64949       March 2, 2019          2015  TV-14     91-120
# 64950       March 2, 2019          2015  TV-14     91-120
#
# [64951 rows x 8 columns]

# %%
constraint=df['director'].tolist()
constraint
new_df = pd.DataFrame(constraint,index=df['show_id']) 
new_df.head()
director_df = pd.DataFrame(new_df.stack(),columns=['Director']).reset_index().iloc[:,[0,2]]
director_df
# Out:
#      show_id         Director
# 0         s1  Kirsten Johnson
# 1         s2      No Director
# 2         s3  Julien Leclercq
# 3         s4      No Director
# 4         s5      No Director
# ...      ...              ...
# 9607   s8803    David Fincher
# 9608   s8804      No Director
# 9609   s8805  Ruben Fleischer
# 9610   s8806     Peter Hewitt
# 9611   s8807      Mozez Singh
#
# [9612 rows x 2 columns]

# %%
df1=pd.merge(left=director_df,right=df1,on='show_id')
df1
# Out:
#       show_id         Director                   Cast     type        country  \
# 0          s1  Kirsten Johnson                 Others    Movie  United States
# 1          s2      No Director             Ama Qamata  TV Show   South Africa
# 2          s2      No Director            Khosi Ngema  TV Show   South Africa
# 3          s2      No Director          Gail Mabalane  TV Show   South Africa
# 4          s2      No Director         Thabang Molaba  TV Show   South Africa
# ...       ...              ...                    ...      ...            ...
# 70807   s8807      Mozez Singh       Manish Chaudhary    Movie          India
# 70808   s8807      Mozez Singh           Meghna Malik    Movie          India
# 70809   s8807      Mozez Singh          Malkeet Rauni    Movie          India
# 70810   s8807      Mozez Singh         Anita Shabdish    Movie          India
# 70811   s8807      Mozez Singh  Chittaranjan Tripathy    Movie          India
#
#                date_added  release_year rating   duration
# 0      September 25, 2021          2020  PG-13      61-90
# 1      September 24, 2021          2021  TV-MA  2 Seasons
# 2      September 24, 2021          2021  TV-MA  2 Seasons
# 3      September 24, 2021          2021  TV-MA  2 Seasons
# 4      September 24, 2021          2021  TV-MA  2 Seasons
# ...                   ...           ...    ...        ...
# 70807       March 2, 2019          2015  TV-14     91-120
# 70808       March 2, 2019          2015  TV-14     91-120
# 70809       March 2, 2019          2015  TV-14     91-120
# 70810       March 2, 2019          2015  TV-14     91-120
# 70811       March 2, 2019          2015  TV-14     91-120
#
# [70812 rows x 9 columns]

# %%
df1.head()
# Out:
#   show_id         Director            Cast     type        country  \
# 0      s1  Kirsten Johnson          Others    Movie  United States
# 1      s2      No Director      Ama Qamata  TV Show   South Africa
# 2      s2      No Director     Khosi Ngema  TV Show   South Africa
# 3      s2      No Director   Gail Mabalane  TV Show   South Africa
# 4      s2      No Director  Thabang Molaba  TV Show   South Africa
#
#            date_added  release_year rating   duration
# 0  September 25, 2021          2020  PG-13      61-90
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA  2 Seasons
# 3  September 24, 2021          2021  TV-MA  2 Seasons
# 4  September 24, 2021          2021  TV-MA  2 Seasons

# %%
constraint=df['listed_in'].tolist()
constraint
new_df = pd.DataFrame(constraint,index=df['show_id']) 
new_df.head()
listed_in_df = pd.DataFrame(new_df.stack(),columns=['listed_in']).reset_index().iloc[:,[0,2]]
listed_in_df
# Out:
#       show_id                 listed_in
# 0          s1             Documentaries
# 1          s2    International TV Shows
# 2          s2                 TV Dramas
# 3          s2              TV Mysteries
# 4          s3            Crime TV Shows
# ...       ...                       ...
# 19318   s8806  Children & Family Movies
# 19319   s8806                  Comedies
# 19320   s8807                    Dramas
# 19321   s8807      International Movies
# 19322   s8807          Music & Musicals
#
# [19323 rows x 2 columns]

# %%
final_df=pd.merge(left=df1,right=listed_in_df,on='show_id')
final_df
# Out:
#        show_id         Director                   Cast     type  \
# 0           s1  Kirsten Johnson                 Others    Movie
# 1           s2      No Director             Ama Qamata  TV Show
# 2           s2      No Director             Ama Qamata  TV Show
# 3           s2      No Director             Ama Qamata  TV Show
# 4           s2      No Director            Khosi Ngema  TV Show
# ...        ...              ...                    ...      ...
# 161211   s8807      Mozez Singh         Anita Shabdish    Movie
# 161212   s8807      Mozez Singh         Anita Shabdish    Movie
# 161213   s8807      Mozez Singh  Chittaranjan Tripathy    Movie
# 161214   s8807      Mozez Singh  Chittaranjan Tripathy    Movie
# 161215   s8807      Mozez Singh  Chittaranjan Tripathy    Movie
#
#               country          date_added  release_year rating   duration  \
# 0       United States  September 25, 2021          2020  PG-13      61-90
# 1        South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2        South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 3        South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 4        South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# ...               ...                 ...           ...    ...        ...
# 161211          India       March 2, 2019          2015  TV-14     91-120
# 161212          India       March 2, 2019          2015  TV-14     91-120
# 161213          India       March 2, 2019          2015  TV-14     91-120
# 161214          India       March 2, 2019          2015  TV-14     91-120
# 161215          India       March 2, 2019          2015  TV-14     91-120
#
#                      listed_in
# 0                Documentaries
# 1       International TV Shows
# 2                    TV Dramas
# 3                 TV Mysteries
# 4       International TV Shows
# ...                        ...
# 161211    International Movies
# 161212        Music & Musicals
# 161213                  Dramas
# 161214    International Movies
# 161215        Music & Musicals
#
# [161216 rows x 10 columns]

# %% [markdown]
# # Analysis

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  \
# 0      s1  Kirsten Johnson       Others    Movie  United States
# 1      s2      No Director   Ama Qamata  TV Show   South Africa
# 2      s2      No Director   Ama Qamata  TV Show   South Africa
# 3      s2      No Director   Ama Qamata  TV Show   South Africa
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa
#
#            date_added  release_year rating   duration               listed_in
# 0  September 25, 2021          2020  PG-13      61-90           Documentaries
# 1  September 24, 2021          2021  TV-MA  2 Seasons  International TV Shows
# 2  September 24, 2021          2021  TV-MA  2 Seasons               TV Dramas
# 3  September 24, 2021          2021  TV-MA  2 Seasons            TV Mysteries
# 4  September 24, 2021          2021  TV-MA  2 Seasons  International TV Shows

# %%
final_df.shape
# Out:
# (161216, 10)

# %%
final_df['Year Added']=final_df['date_added'].apply(lambda x : int(x.split()[2]))

# %%
final_df['Month Added']=final_df['date_added'].apply(lambda x : x.split()[0])

# %%
final_df.drop(columns='date_added',inplace=True)

# %% [markdown]
# # Question 1 :
# ### How has the number of movies and TV Shows released per year changed over the last 10 years?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
final_df['release_year'].unique()
# Out:
# array([2020, 2021, 1993, 2018, 1996, 1998, 1997, 2010, 2013, 2017, 1975,
#        1978, 1983, 1987, 2012, 2001, 2014, 2002, 2003, 2004, 2011, 2008,
#        2009, 2007, 2005, 2006, 1994, 2015, 2019, 2016, 1982, 1989, 1990,
#        1991, 1999, 1986, 1992, 1984, 1980, 1961, 2000, 1995, 1985, 1976,
#        1959, 1988, 1981, 1972, 1964, 1945, 1954, 1979, 1958, 1956, 1963,
#        1970, 1973, 1925, 1974, 1960, 1966, 1971, 1962, 1969, 1977, 1967,
#        1968, 1965, 1946, 1942, 1955, 1944, 1947, 1943], dtype=int64)

# %%
release_year_plot=final_df.groupby(by=['type','release_year']).nunique()['show_id']
release_year_plot
# Out:
# type     release_year
# Movie    1942              2
#          1943              3
#          1944              3
#          1945              3
#          1946              1
#                         ...
# TV Show  2017            265
#          2018            380
#          2019            397
#          2020            436
#          2021            315
# Name: show_id, Length: 119, dtype: int64

# %%
movies_year_wise=release_year_plot.loc['Movie'].sort_values(ascending=False)
movies_year_wise
# Out:
# release_year
# 2018    767
# 2017    767
# 2016    658
# 2019    633
# 2020    517
#        ...
# 1961      1
# 1963      1
# 1966      1
# 1947      1
# 1946      1
# Name: show_id, Length: 73, dtype: int64

# %%
tvshows_year_wise=release_year_plot.loc['TV Show'].sort_values(ascending=False)
tvshows_year_wise
# Out:
# release_year
# 2020    436
# 2019    397
# 2018    380
# 2021    315
# 2017    265
# 2016    244
# 2015    162
# 2014     88
# 2012     64
# 2013     63
# 2011     40
# 2010     40
# 2009     34
# 2008     23
# 2007     14
# 2006     14
# 2005     13
# 2003     10
# 2004      9
# 2002      7
# 1999      7
# 2001      5
# 1997      4
# 1993      4
# 1998      4
# 2000      4
# 1990      3
# 1992      3
# 1996      3
# 1994      2
# 1995      2
# 1988      2
# 1986      2
# 1977      1
# 1963      1
# 1946      1
# 1967      1
# 1972      1
# 1974      1
# 1989      1
# 1979      1
# 1981      1
# 1985      1
# 1991      1
# 1945      1
# 1925      1
# Name: show_id, dtype: int64

# %%
plt.figure(dpi=150)
sns.barplot(x=movies_year_wise.index[:10],
            y=movies_year_wise[:10])
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('No Of Movies')
plt.title('Number of Movies released per year changed in last 10 years')
plt.savefig('Image1.jpg')
plt.show()

# %%
plt.figure(dpi=150)
sns.barplot(x=tvshows_year_wise.index[:10],
            y=tvshows_year_wise[:10])
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('No Of TV Shows')
plt.title('Number of TV Shows released per year changed in last 10 years')
plt.savefig('Image2.jpg')
plt.show()

# %% [markdown]
# # Question 2 :
# ### How has the number of Movies and TV Shows added to Netflix per year changed over the last 10 years?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
added_year_plot=final_df.groupby(by=['type','Year Added']).nunique()['show_id']
added_year_plot
# Out:
# type     Year Added
# Movie    2008             1
#          2009             2
#          2010             1
#          2011            13
#          2012             3
#          2013             6
#          2014            19
#          2015            56
#          2016           253
#          2017           839
#          2018          1237
#          2019          1424
#          2020          1284
#          2021           993
# TV Show  2008             1
#          2013             5
#          2014             5
#          2015            26
#          2016           176
#          2017           349
#          2018           412
#          2019           592
#          2020           595
#          2021           515
# Name: show_id, dtype: int64

# %%
movies_added_per_year=added_year_plot.loc['Movie'].sort_values(ascending=False)
movies_added_per_year
# Out:
# Year Added
# 2019    1424
# 2020    1284
# 2018    1237
# 2021     993
# 2017     839
# 2016     253
# 2015      56
# 2014      19
# 2011      13
# 2013       6
# 2012       3
# 2009       2
# 2008       1
# 2010       1
# Name: show_id, dtype: int64

# %%
tvshow_added_per_year=added_year_plot.loc['TV Show'].sort_index(ascending=False)
tvshow_added_per_year
# Out:
# Year Added
# 2021    515
# 2020    595
# 2019    592
# 2018    412
# 2017    349
# 2016    176
# 2015     26
# 2014      5
# 2013      5
# 2008      1
# Name: show_id, dtype: int64

# %%
plt.figure(dpi=150)
sns.barplot(x=list(tvshow_added_per_year.index[:9])+[2012],
            y=list(tvshow_added_per_year[:9])+[0])
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('No Of TV Shows')
plt.title('Number of TV Shows added to Netflix per year in the last 10 years?')
plt.savefig('Image3.jpg')
plt.show()

# %%
plt.figure(dpi=150)
sns.barplot(x=movies_added_per_year.index[:10],
            y=movies_added_per_year[:10])
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('No Of TV Shows')
plt.title('Number of Movies added to Netflix per year changed in last 10 years?')
plt.savefig('Image4.jpg')
plt.show()

# %% [markdown]
# # Question 3 :
# ### In which months does Netflix add maximum content?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
month_year_plot=final_df.groupby(by='Month Added').nunique()['show_id'].sort_values(ascending=False)
month_year_plot
# Out:
# Month Added
# July         827
# December     813
# September    780
# April        764
# October      760
# August       755
# March        742
# January      738
# June         728
# November     705
# May          632
# February     563
# Name: show_id, dtype: int64

# %%
plt.figure(dpi=150)
sns.barplot(x=list(month_year_plot.index),y=list(month_year_plot))
plt.xticks(rotation=90)
plt.xlabel('Month')
plt.ylabel('No Of Content')
plt.title('In which months does Netflix add maximum content ?')
plt.savefig('Image5.jpg')
plt.show()

# %% [markdown]
# # Question 4 :
# ### Which directors are the most popular?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
director_plot=final_df.groupby('Director').nunique()['show_id'].sort_values(ascending=False)
director_plot
# Out:
# Director
# No Director                2634
# Rajiv Chilaka                22
# Jan Suter                    21
# Raúl Campos                  19
# Suhas Kadav                  16
#                            ...
# Brandon Camp                  1
# Juan Antin                    1
# Juan Antonio de la Riva       1
# Juan Camilo Pinzon            1
# María Jose Cuevas             1
# Name: show_id, Length: 4994, dtype: int64

# %%
plt.figure(dpi=150)
sns.barplot(x=list(director_plot.index[1:11]),y=list(director_plot[1:11]))
plt.xticks(rotation=90)
plt.xlabel('Directors')
plt.ylabel('No Of Content')
plt.title('Which directors are the most popular?')
plt.savefig('Image6.jpg')
plt.show()

# %% [markdown]
# # Question 5 :
# ### Which cast members are the most popular?

# %%
cast_plot=final_df.groupby('Cast').nunique()['show_id'].sort_values(ascending=False)
cast_plot
# Out:
# Cast
# Others              825
# Anupam Kher          43
# Shah Rukh Khan       35
# Julie Tejwani        33
# Naseeruddin Shah     32
#                    ...
# Jamie Lee             1
# Jamie Kenna           1
# Jamie Kaler           1
# Jamie Johnston        1
# Ṣọpẹ́ Dìrísù          1
# Name: show_id, Length: 36440, dtype: int64

# %%
plt.figure(dpi=150)
sns.barplot(x=list(cast_plot.index[1:11]),y=list(cast_plot[1:11]))
plt.xticks(rotation=90)
plt.xlabel('Cast Members')
plt.ylabel('No Of Content')
plt.title('Which cast members are the most popular?')
plt.savefig('Image7.jpg')
plt.show()

# %% [markdown]
# # Question 6 :
# ### What type of content is mostly added in Netflix in the last 3 years?

# %%
cast_plot=final_df[final_df['Year Added']>=2019].groupby('type').nunique()['show_id'].sort_values(ascending=False)
cast_plot
# Out:
# type
# Movie      3701
# TV Show    1702
# Name: show_id, dtype: int64

# %%
plt.figure(dpi=150)
sns.barplot(x=list(cast_plot.index),y=list(cast_plot))

plt.xlabel('Type Of Content')
plt.ylabel('No Of Content')
plt.title('What type of content is added in Netflix in last 3 years?')
plt.savefig('Image8.jpg')
plt.show()

# %% [markdown]
# # Question 7 :
# ### In which country is more movies produced?

# %%
country_plot=final_df.groupby('country').nunique()['show_id'].sort_values(ascending=False)
country_plot
plt.figure(dpi=150)
sns.barplot(x=list(country_plot.iloc[[0, 1, 3, 4, 5, 6, 7, 8, 9, 10]].index),
            y=list(country_plot.iloc[[0, 1, 3, 4, 5, 6, 7, 8, 9, 10]]))
plt.xlabel('Country')
plt.ylabel('No Of Content')
plt.title('In which country is more movies produced ?')
plt.xticks(rotation=90)
plt.savefig('Image9.jpg')
plt.show()

# %% [markdown]
# # Question 8 :
# ### What kind of rated content is most available in Netflix?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
final_df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# - TV-Y - Designed to be appropriate for all children
#
# - TV-Y7 - Suitable for ages 7 and up
#
# - G - Suitable for General Audiences
#
# - TV-G - Suitable for General Audiences
#
# - PG - Parental Guidance suggested
#
# - TV-PG - Parental Guidance suggested
#
# - PG-13 - Parents strongly cautioned. May be Inappropriate for ages 12 and under.
#
# - TV-14 - Parents strongly cautioned. May not be suitable for ages 14 and under.
#
# - R - Restricted. May be inappropriate for ages 17 and under.
#
# - TV-MA - For Mature Audiences. May not be suitable for ages 17 and under.
#
# - NC-17 - Inappropriate for ages 17 and under
#
# - NR - Stands for No Result. It occurs when a film is not submitted to the MPAA for rating.
#
# - UR - It means unrated, which means the film hasn’t been submitted to the MPAA for a rating.
#
# - TV-Y7-FV - Indicates that the content is designed for children aged 7 and older, and contains “fantasy violence” that may be more intense or combative than other TV-Y7 programs.

# %%
rating_plot=final_df.groupby('rating').nunique()['show_id'].sort_values(ascending=False)
rating_plot
plt.figure(dpi=150)
sns.barplot(x=list(rating_plot.index[:5]),
            y=list(rating_plot[:5]))
plt.xticks(rotation=90)
plt.xlabel('Rated Content')
plt.ylabel('No Of Content')
plt.title('What kind of rated content is most available in Netflix?')
plt.savefig('Image10.jpg')
plt.show()

# %% [markdown]
# # Question 9 :
# ### Which is the most popular genre?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
listed_in_plot=final_df.groupby('listed_in').nunique()['show_id'].sort_values(ascending=False)
listed_in_plot
plt.figure(dpi=150)
sns.barplot(x=list(listed_in_plot.index[:10]),
            y=list(listed_in_plot[:10]))
plt.xlabel('Genre')
plt.ylabel('No Of Content')
plt.title('Which is the most popular genre?')
plt.xticks(rotation=90)
plt.savefig('Image11.jpg')
plt.show()

# %% [markdown]
# # Question 10 :
# ### What is the most preferred duration for each type of content?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
duration_plot=final_df.groupby(by=['type','duration']).nunique()['show_id']
duration_plot
# Out:
# type     duration
# Movie    0-30           130
#          121-150        897
#          151-180        198
#          31-60          357
#          61-90         1506
#          91-120        2996
#          Above 180       47
# TV Show  1 Season      1793
#          10 Seasons       7
#          11 Seasons       2
#          12 Seasons       2
#          13 Seasons       3
#          15 Seasons       2
#          17 Seasons       1
#          2 Seasons      425
#          3 Seasons      199
#          4 Seasons       95
#          5 Seasons       65
#          6 Seasons       33
#          7 Seasons       23
#          8 Seasons       17
#          9 Seasons        9
# Name: show_id, dtype: int64

# %%
movie_plot=duration_plot.loc['Movie'].sort_values(ascending=False)
movie_plot
# Out:
# duration
# 91-120       2996
# 61-90        1506
# 121-150       897
# 31-60         357
# 151-180       198
# 0-30          130
# Above 180      47
# Name: show_id, dtype: int64

# %%
tv_show_plot=duration_plot.loc['TV Show'].sort_values(ascending=False)
tv_show_plot
# Out:
# duration
# 1 Season      1793
# 2 Seasons      425
# 3 Seasons      199
# 4 Seasons       95
# 5 Seasons       65
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       7
# 13 Seasons       3
# 11 Seasons       2
# 12 Seasons       2
# 15 Seasons       2
# 17 Seasons       1
# Name: show_id, dtype: int64

# %%
plt.figure(dpi=150)
sns.barplot(x=movie_plot.index[:5],
            y=list(movie_plot[:5]))
# plt.xticks(rotation=90)
plt.xlabel('Duration in minutes')
plt.ylabel('No Of Content')
plt.title('What is the most preferred duration for Movies')
plt.savefig('Image12.jpg')
plt.show()

# %%
plt.figure(dpi=150)
sns.barplot(x=list(tv_show_plot.index[:5]),
            y=list(tv_show_plot[:5]))
# plt.xticks(rotation=90)
plt.xlabel('Duration in Seasons')
plt.ylabel('No Of Content')
plt.title('What is the most preferred duration for TV Shows?')
plt.savefig('Image13.jpg')
plt.show()

# %% [markdown]
# # Question 11:
# ### No of content added in Netflix in each month over the last 5 years?

# %%
final_df.head()
# Out:
#   show_id         Director         Cast     type        country  release_year  \
# 0      s1  Kirsten Johnson       Others    Movie  United States          2020
# 1      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 2      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 3      s2      No Director   Ama Qamata  TV Show   South Africa          2021
# 4      s2      No Director  Khosi Ngema  TV Show   South Africa          2021
#
#   rating   duration               listed_in  Year Added Month Added
# 0  PG-13      61-90           Documentaries        2021   September
# 1  TV-MA  2 Seasons  International TV Shows        2021   September
# 2  TV-MA  2 Seasons               TV Dramas        2021   September
# 3  TV-MA  2 Seasons            TV Mysteries        2021   September
# 4  TV-MA  2 Seasons  International TV Shows        2021   September

# %%
year_month_df = final_df.groupby(['Year Added','Month Added']).nunique()['show_id']
year_month_df=year_month_df.loc[[2017,2018,2019,2020,2021]]
year_month_df
# Out:
# Year Added  Month Added
# 2017        April           93
#             August         115
#             December       118
#             February        82
#             January         72
#             July            79
#             June            94
#             March          125
#             May             86
#             November        85
#             October        126
#             September      113
# 2018        April          115
#             August         164
#             December       185
#             February        87
#             January        129
#             July           152
#             June            78
#             March          173
#             May             97
#             November       154
#             October        191
#             September      124
# 2019        April          162
#             August         131
#             December       215
#             February       148
#             January        153
#             July           157
#             June           168
#             March          172
#             May            139
#             November       255
#             October        193
#             September      123
# 2020        April          177
#             August         129
#             December       169
#             February       114
#             January        205
#             July           146
#             June           156
#             March          137
#             May            157
#             November       154
#             October        167
#             September      168
# 2021        April          188
#             August         178
#             February       109
#             January        132
#             July           257
#             June           207
#             March          112
#             May            132
#             September      193
# Name: show_id, dtype: int64

# %%
def function(series):
    indexes=set(series.index)
    dict1={}
    for month in ['January','February','March','April','May',
                'June','July','August','September','October','November','December']:
        
        if month in indexes:
            dict1[month]=series.loc[month]
        
        else:
            dict1[month]=0
        
    return pd.Series(dict1)

# %%
plt.figure(dpi=150)
for year in [2017,2018,2019,2020,2021]:
    series=function(year_month_df.loc[year])
    sns.lineplot(x=['January','February','March','April','May',
                'June','July','August','September','October','November','December'],
                y=series.loc[['January','February','March','April','May',
                'June','July','August','September','October','November','December']])
plt.legend([2017,2018,2019,2020,2021])
plt.xticks(rotation=90)
plt.xlabel('Month')
plt.ylabel('No Of Content')
plt.title('No of content added in Netflix in each month in last 5 years?')
plt.savefig('Image14.jpg')
plt.show()

# %% [markdown]
# # Final Analysis

# %% [markdown]
# The given dataset has 8807 rows and 12 columns, out of which we can drop 2 columns - description and title, which are nominal columns and would not provide much scope for deriving insights from the data, which would leave us with 10 columns. The grain of the data is the column show_id which is a unique identifier for every row. All the columns are of object type except release year, which is of the type integer. From the column date_added, we can make 2 new columns - Year Added of type integer and Month Added of type object and finally drop the original column date_added. We would finally be left with 11 columns in total.
#
# Using the info method, we observed that the columns - director, cast, country, date_added, rating and duration had Nan values. All of the Nan values were filled with a certain value depending on the count of missing values and nature of the column, and none of the rows were dropped.
#
#
# At the end of the above steps, all the 11 columns had 8807 non-null values.

# %% [markdown]
# # Recommendations :
#
# - Since from the last few years, there has been an increase in the no of TV shows being released and added on Netflix year on year, and decrease in the no of movies being released and added on Netflix year on year, it shows that there is an increasing demand for TV shows, and therefore Netflix should try to add more TV shows going forward.
#
#
# - Even though there has been an increasing trend for TV shows, but in the last 3 years, the no of movies added compared to TV shows is twice, therefore Netflix should try to add more TV shows on its platform.
#
#
# - The months May and February are the months in which content added on Netflix is the least. Therefore Netflix can try to add more content in these 2 months to ensure that people have enough content options during May and February.
#
#
# - Netflix should try to add more content for the most popular directors such as Rajiv Chilaka, Jan Suter and Raul Campos.
#
#
# - Netflix should try to add more content for the most popular casts such as Anupam Kher and Shahrukh Khan. Also, the presence of casts such as Julie Tejwani, Rupa Bhimani and Takahiro Sakurai in the top 10 tells us that animated movies are very popular and Netflix should try to add more animated movies as well.
#
#
# - Netflix should try to add more content having ratings â€“ TV-MA and TV-14.
#
#
# - Netflix should try to add more content which are produced in the United States, as clearly it is the most popular country where content is produced.
#
#
# - Netflix should try to add more movies which have a duration in the range of 91 to 120 minutes.
#
#
# - Netflix should try to add more TV shows which have 1 season.
#
#
# - Netflix should try to add more content for the genres - International Movies, Dramas and Comedies.
